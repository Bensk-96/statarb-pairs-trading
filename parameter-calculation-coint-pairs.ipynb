# %%
import os
import json
import requests

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go

from alpaca_trade_api.rest import REST, TimeFrame
from datetime import datetime

import dask
import dask.bag as db
from dask.diagnostics import ProgressBar

import statsmodels.api as sm 
from typing import Optional , Tuple

import ast

# %%
key = json.loads(open("key.txt","r").read())
api_key_id = key["APCA-API-KEY-ID"]
api_secret_key = key["APCA-API-SECRET-KEY"]

headers = {
    "accept": "application/json",
    "APCA-API-KEY-ID": api_key_id,
    "APCA-API-SECRET-KEY": api_secret_key
}

api = REST(api_key_id, api_secret_key, base_url='https://data.alpaca.markets/v2')

# %%
# Get NYSE Open days from 2024-06-01 to 2024-08-31

url = "https://paper-api.alpaca.markets/v2/calendar?start=2024-06-01T00%3A00%3A00Z&end=2024-08-31T23%3A59%3A59Z"
response = requests.get(url, headers=headers)
df_market_hours = pd.DataFrame(response.json())

market_open_days = df_market_hours.date

print(market_open_days.head())
# Out:
# 0    2024-06-03
# 1    2024-06-04
# 2    2024-06-05
# 3    2024-06-06
# 4    2024-06-07
# Name: date, dtype: object

# %%
## Get trading day and the corresponding parameter formation days

lookback = 2
formation_and_trading_days = []

for i in range(lookback, len(market_open_days)):
    trade_day = datetime.strptime(market_open_days[i], '%Y-%m-%d').strftime('%Y%m%d')
    formation_days = []
    for j in range(lookback, 0 , -1):
        formation_days.append(datetime.strptime(market_open_days[(i - j)], '%Y-%m-%d').strftime('%Y%m%d'))
    formation_and_trading_days.append({"Trading Day":trade_day , "Formation Days":formation_days})

print(formation_and_trading_days[0 : 2])
# Out:
# [{'Trading Day': '20240605', 'Formation Days': ['20240603', '20240604']}, {'Trading Day': '20240606', 'Formation Days': ['20240604', '20240605']}]

# %%
# Find unique pairs among the symbols

from itertools import combinations 
#symbol_list = ["SMH", "SOXX","NVDA", "TSM", "AVGO", "TXN", "AMD", "ASML", "ADI", "AMAT", "QCOM", "KLAC","INTC"] ## drop TXN, ADI, KLAC, AVGO
symbol_list = ["SMH", "SOXX","NVDA", "TSM", "AMD", "ASML", "AMAT", "QCOM","INTC"]
pairs = list(combinations(symbol_list, 2))

# %%
def load_quote_data(symbol: str, date: str) -> pd.DataFrame:
    csv_name = f"{symbol}_{date}_quote.csv"
    quote_data = pd.read_csv(f"data/{csv_name}", sep=",")
    
    # Convert timestamp to datetime, handling potential errors
    try:
        quote_data['timestamp'] = pd.to_datetime(quote_data['timestamp']) 
    except ValueError as e:
        print(f"Error parsing timestamps for {symbol}: {e}")
        # Optionally use coerce to handle this
        quote_data['timestamp'] = pd.to_datetime(quote_data['timestamp'], errors='coerce')
    
    quote_data.set_index('timestamp', inplace=True)
    return quote_data

def calculate_midprice_and_downsample(quote_data : pd.DataFrame , downsample : int) -> pd.Series:
    quote_data["mid_price"] = np.where(
        (quote_data["ask_price"] > 0) & (quote_data["bid_price"] > 0),
        (quote_data["ask_price"] + quote_data["bid_price"]) * 0.5,
        np.nan
    )
    downsampled_mid_price = quote_data["mid_price"].resample(f'{downsample}S').last()
    downsampled_mid_price = downsampled_mid_price.fillna(method='ffill')
    #print(type(downsampled_mid_price))
    return downsampled_mid_price

# %%
def calculate_half_life(spread : np.ndarray) -> float:
    # Ensure spread is a Pandas Series for easy manipulation
    df_spread = pd.DataFrame(spread, columns=["spread"])
    
    # Calculate lagged spread and spread returns
    spread_lag = df_spread.spread.shift(1).fillna(method="bfill")  # Backfill the first NaN
    spread_ret = df_spread.spread - spread_lag

    # Add a constant to the lagged spread
    spread_lag2 = sm.add_constant(spread_lag)
    
    # Fit the OLS model
    model = sm.OLS(spread_ret, spread_lag2)
    res = model.fit()

    # Calculate the half-life
    halflife = -np.log(2) / res.params[1]
    
    return round(halflife, 0)

def cointegration_check(price_data: pd.DataFrame, asset1: str, asset2: str) -> Tuple[bool, Optional[dict]]:
    #print("--------------------")
    #print(f"Check cointegration of {asset1} and {asset2}")

    # Step 1: Perform OLS regression
    model1 = sm.OLS(price_data[asset2], sm.add_constant(price_data[asset1])).fit()
    res = model1.resid  # Note the change to model1.resid

    # Calculate the mean and std of the residual
    res_mean = np.mean(res)
    res_std = np.std(res)
    rsquared_adj = model1.rsquared_adj
    const = model1.params[0]
    hedge_ratio = model1.params[1]
    half_life = calculate_half_life(np.array(res))
    #hurst_exponent = hurst(res)

    #print(model1.summary())  # Also corrected from 'model' to 'model1'

    # Step 2: ADF test on residuals
    adf_test_result = sm.tsa.stattools.adfuller(res)
    p_value_adf_test = adf_test_result[1]

    if p_value_adf_test > 0.05:
        #print(f"{asset1} and {asset2} are not cointegrated (ADF p-value: {p_value_adf_test})")
        return False, None

    #print("Estimate Error Correction Model (ECM)")
    
    # Step 3: Error Correction Model (ECM)
    # Include lagged residuals and the difference of asset1 as regressors
    asset1_diff = sm.add_constant(pd.concat([price_data[asset1].diff(), res.shift(1)], axis=1).dropna())
    asset2_diff = price_data[asset2].diff().dropna()
    
    # Aligning asset1_diff and asset2_diff to ensure they have the same length
    #asset1_diff = asset1_diff.dropna()
    #asset2_diff = asset2_diff.dropna()
    asset1_diff = asset1_diff.loc[asset2_diff.index]
    
    model2 = sm.OLS(asset2_diff, asset1_diff).fit()

    #print(model2.summary())

    # Step 4: Check if the adjustment coefficient is negative
    adjustment_coefficient = list(model2.params)[-1]

    coint_result = {"asset 1": asset1,
                    "asset 2": asset2,
                    "res mean":res_mean ,
                    "res std":res_std,
                    "adj rsquared": rsquared_adj,
                    "constant":const,
                    "hedge ratio": hedge_ratio,
                    "half life": half_life,
                    #"hurst exponent" : hurst_exponent,
                    "p-value of adf test" : p_value_adf_test,
                    "adjustment coef":adjustment_coefficient}
    
    if adjustment_coefficient > 0:
        #print(f"{asset1} and {asset2} are not cointegrated (Adjustment coefficient: {adjustment_coefficient})")
        return False, None
    else:
        #print(f"{asset1} and {asset2} are cointegrated")
        return True, coint_result

def cointegration_check_weighted(price_data: pd.DataFrame, asset1: str, asset2: str) -> Tuple[bool, Optional[dict]]:
    #print("--------------------")
    #print(f"Check cointegration of {asset1} and {asset2}")
    
    res_mean = 0 
    res_std = 0
    rsquared_adj = 0
    const = 0
    hedge_ratio = 0 
    half_life = 0
    #hurst_exponent = 0
    p_value_adf_test = 0
    adjustment_coefficient = 0
    length = len(price_data)

    
    price_data["date"] = price_data.index.date
    unique_date = price_data["date"].unique()

    for date in unique_date:

        price_data_by_date = price_data[price_data.date == date]
        weight = len(price_data_by_date) / length
    
        # Step 1: Perform OLS regression
        model1 = sm.OLS(price_data_by_date[asset2], sm.add_constant(price_data_by_date[asset1])).fit()
        res_by_date = model1.resid  # Note the change to model1.resid

        # Calculate the mean and std of the residual
        res_mean_by_date = np.mean(res_by_date)
        res_std_by_date= np.std(res_by_date)
        rsquared_adj_by_date = model1.rsquared_adj
        const_by_date = model1.params[0]
        hedge_ratio_by_date = model1.params[1]
        half_life_by_date = calculate_half_life(np.array(res_by_date))   
        #hurst_exponent_by_date = hurst(res_by_date)

        # Step 2: ADF test on residuals
        adf_test_result_by_date = sm.tsa.stattools.adfuller(res_by_date)
        p_value_adf_test_by_date = adf_test_result_by_date[1]   

        # Step 3: Error Correction Model (ECM)
        # Include lagged residuals and the difference of asset1 as regressors
        asset1_diff = sm.add_constant(pd.concat([price_data_by_date[asset1].diff(), res_by_date.shift(1)], axis=1).dropna())
        asset2_diff = price_data_by_date[asset2].diff().dropna()

        # Aligning asset1_diff and asset2_diff to ensure they have the same length
        #asset1_diff = asset1_diff.dropna()
        #asset2_diff = asset2_diff.dropna()
        asset1_diff = asset1_diff.loc[asset2_diff.index]

        model2 = sm.OLS(asset2_diff, asset1_diff).fit()

        # Step 4: Check if the adjustment coefficient is negative
        adjustment_coefficient_by_date = list(model2.params)[-1]

        res_mean += res_mean_by_date * weight 
        res_std += res_std_by_date * weight 
        rsquared_adj += rsquared_adj_by_date * weight
        const += const_by_date * weight
        hedge_ratio += hedge_ratio_by_date * weight
        half_life += half_life_by_date * weight
        #hurst_exponent += hurst_exponent_by_date * weight
        #p_value_adf_test += p_value_adf_test_by_date * weight
        p_value_adf_test = max(p_value_adf_test_by_date, p_value_adf_test)
        adjustment_coefficient += adjustment_coefficient_by_date * weight


    coint_result = {"asset 1": asset1,
                    "asset 2": asset2,
                    "res mean":res_mean ,
                    "res std":res_std,
                    "adj rsquared": rsquared_adj,
                    "constant" : const,
                    "hedge ratio": hedge_ratio,
                    "half life": half_life,
                    #"hurst exponent": hurst_exponent,
                    "p-value of adf test" : p_value_adf_test,
                    "adjustment coef":adjustment_coefficient}
    
    if (p_value_adf_test < 0.05 ) and (adjustment_coefficient < 0):
        return True, coint_result
    else:
        return False, None

# %%
## use find co-integrated pairs and the corresponding parameters in historical data
## use dask for parallel computation to accelerate the calculation
from dask.distributed import Client
client = Client(n_workers=20)  # Adjust based on your CPU cores

def parallel_process(func, data, **kwargs):
    with ProgressBar():
        results = db.from_sequence(data).map(lambda x: func(x, **kwargs)).compute()
    return results

def process_day(day : dict, symbol_list : list, pairs : list , downsample : int, weighted : bool = True) -> dict:

    try:
        trading_day = day["Trading Day"]   
        df_mid_price = pd.DataFrame({})

        for formation_day in day["Formation Days"]: 
            midprice_by_formation_day = pd.DataFrame()
            for symbol in symbol_list:
                quote_data_by_symbol = load_quote_data(symbol= symbol, date=formation_day)
                downsampled_mid_price_by_symbol = calculate_midprice_and_downsample(quote_data = quote_data_by_symbol, downsample = downsample)
                midprice_by_formation_day[symbol] = downsampled_mid_price_by_symbol

            df_mid_price = pd.concat([df_mid_price, midprice_by_formation_day])
            df_mid_price = df_mid_price.fillna(method='ffill')
            df_mid_price = df_mid_price.fillna(method='bfill')

        coint_pair_and_params_by_day = []

        for pair in pairs:
            if weighted:
                coint_result = cointegration_check_weighted(df_mid_price, pair[0], pair[1]) 
            else:
                coint_result = cointegration_check(df_mid_price, pair[0], pair[1])   
            if coint_result[0]: 
                coint_pair_and_params_by_day.append(coint_result[1])

        return {"Trading Day": trading_day, "Coint Pairs and Params": coint_pair_and_params_by_day}
    
    except (IndexError, ValueError) as e:
        print(f"Error processing day {trading_day}: {e}")
        return {"Trading Day": trading_day, "Coint Pairs and Params": []}

if __name__ == "__main__":
    # Pass the necessary arguments to the parallel process function
    results = parallel_process(
        process_day, 
        formation_and_trading_days, 
        symbol_list=symbol_list, 
        pairs=pairs, 
        downsample=60, ## intercal for resampling the mid-price. Use 5s, 10s, 20s, 30s...
        weighted=True
    )

    # You can now aggregate results or process them further
    for result in results:
        print(result)
# Out:
# c:\Users\Benjamin_Chan\Documents\Python Scripts\Finance\statarb\myenv\lib\site-packages\distributed\node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 52853 instead
#   warnings.warn(
# C:\Users\Benjamin_Chan\AppData\Local\Programs\Python\Python38\lib\contextlib.py:120: UserWarning: Creating scratch directories is taking a surprisingly long time. (1.30s) This is often due to running workers on a network file system. Consider specifying a local-directory to point workers to write scratch data to a local disk.
#   next(self.gen)
# {'Trading Day': '20240605', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'TSM', 'res mean': -1.0629719326971098e-12, 'res std': 0.3342293809181469, 'adj rsquared': 0.6743598760271154, 'constant': 17.52860457580286, 'hedge ratio': 0.5610625446460012, 'half life': 16.0, 'p-value of adf test': 0.014969716427744025, 'adjustment coef': -0.043945058583503435}, {'asset 1': 'SOXX', 'asset 2': 'TSM', 'res mean': -4.2083442144175e-12, 'res std': 0.3748594884310825, 'adj rsquared': 0.5907157241660228, 'constant': 38.73732770069715, 'hedge ratio': 0.49161936398860906, 'half life': 17.0, 'p-value of adf test': 0.012354724209240242, 'adjustment coef': -0.03806959696268971}]}
# {'Trading Day': '20240606', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'SOXX', 'res mean': 1.0359713087382262e-12, 'res std': 0.13090212162445275, 'adj rsquared': 0.9807263069558536, 'constant': 17.769629893260444, 'hedge ratio': 0.8875352821629328, 'half life': 5.0, 'p-value of adf test': 0.008397351386558427, 'adjustment coef': -0.14049600220085676}, {'asset 1': 'SMH', 'asset 2': 'AMAT', 'res mean': 4.498318526785647e-12, 'res std': 0.7262653791495419, 'adj rsquared': 0.8237670056113511, 'constant': -94.38344070492838, 'hedge ratio': 1.2687083866724975, 'half life': 7.0, 'p-value of adf test': 0.03279312420093352, 'adjustment coef': -0.11089434070666475}, {'asset 1': 'AMAT', 'asset 2': 'QCOM', 'res mean': 4.924243349262561e-13, 'res std': 0.6382764134199754, 'adj rsquared': 0.7734527392659674, 'constant': 59.29397151961477, 'hedge ratio': 0.6816147655104595, 'half life': 7.5, 'p-value of adf test': 0.048654279008158385, 'adjustment coef': -0.05539016472189014}, {'asset 1': 'AMAT', 'asset 2': 'INTC', 'res mean': 5.575027619040741e-15, 'res std': 0.1425845798484672, 'adj rsquared': 0.5733254042201041, 'constant': 4.25788937192527, 'hedge ratio': 0.12311577663449921, 'half life': 20.0, 'p-value of adf test': 0.04325689890300297, 'adjustment coef': -0.010803623512346237}]}
# {'Trading Day': '20240607', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'SOXX', 'res mean': -2.8806860031274996e-12, 'res std': 0.16721063042487086, 'adj rsquared': 0.9880683858145282, 'constant': 38.63220469778231, 'hedge ratio': 0.8001923242845108, 'half life': 7.5, 'p-value of adf test': 0.008011077126559024, 'adjustment coef': -0.10002291054210427}, {'asset 1': 'SMH', 'asset 2': 'INTC', 'res mean': -4.4900379710573667e-13, 'res std': 0.07476565812496527, 'adj rsquared': 0.7695088379525084, 'constant': 12.485042887180235, 'hedge ratio': 0.0713388537628057, 'half life': 18.5, 'p-value of adf test': 0.0034741545836390114, 'adjustment coef': -0.021232008085757842}, {'asset 1': 'SOXX', 'asset 2': 'TSM', 'res mean': 3.227940991424615e-12, 'res std': 0.5611239671946475, 'adj rsquared': 0.9445847661932005, 'constant': -173.2952121373829, 'hedge ratio': 1.3996261053373726, 'half life': 16.0, 'p-value of adf test': 0.030492997595967, 'adjustment coef': -0.024214313880117036}, {'asset 1': 'SOXX', 'asset 2': 'INTC', 'res mean': -4.425451458281224e-13, 'res std': 0.06709765905110632, 'adj rsquared': 0.807912944864291, 'constant': 8.52285185961494, 'hedge ratio': 0.09130633059015009, 'half life': 16.5, 'p-value of adf test': 0.0041972845959393525, 'adjustment coef': -0.028054167364671263}, {'asset 1': 'TSM', 'asset 2': 'INTC', 'res mean': -2.451600176428679e-13, 'res std': 0.07418779234000808, 'adj rsquared': 0.7371798921295959, 'constant': 19.45309821916486, 'hedge ratio': 0.06764745266514192, 'half life': 20.5, 'p-value of adf test': 0.025389269651603683, 'adjustment coef': -0.02947310323683027}, {'asset 1': 'AMAT', 'asset 2': 'INTC', 'res mean': -8.682695588154624e-13, 'res std': 0.07725128467277553, 'adj rsquared': 0.7291082526416244, 'constant': 11.994300234733164, 'hedge ratio': 0.08329438326764893, 'half life': 19.0, 'p-value of adf test': 0.008653846024913646, 'adjustment coef': -0.031460547817279645}]}
# {'Trading Day': '20240610', 'Coint Pairs and Params': []}
# {'Trading Day': '20240611', 'Coint Pairs and Params': []}
# {'Trading Day': '20240612', 'Coint Pairs and Params': []}
# {'Trading Day': '20240613', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'TSM', 'res mean': 1.1538849647853895e-12, 'res std': 0.39166187417032633, 'adj rsquared': 0.8540184650431348, 'constant': -49.755847386098154, 'hedge ratio': 0.8520158391754448, 'half life': 9.0, 'p-value of adf test': 0.02938793299370879, 'adjustment coef': -0.07220635563999565}, {'asset 1': 'SOXX', 'asset 2': 'ASML', 'res mean': -2.9981551144887e-11, 'res std': 2.7403360299090442, 'adj rsquared': 0.7246750555810757, 'constant': -160.96619148692864, 'hedge ratio': 4.900248175652828, 'half life': 10.0, 'p-value of adf test': 0.029722608314712975, 'adjustment coef': -0.0719798444946525}, {'asset 1': 'SOXX', 'asset 2': 'QCOM', 'res mean': -6.428990673157386e-12, 'res std': 0.5187434731251972, 'adj rsquared': 0.8328709342616517, 'constant': -55.308690404476415, 'hedge ratio': 1.0890395335707659, 'half life': 9.5, 'p-value of adf test': 0.04963101052280145, 'adjustment coef': -0.05057968508140154}]}
# {'Trading Day': '20240614', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'TSM', 'res mean': -1.0863651858436732e-12, 'res std': 0.5654160493621764, 'adj rsquared': 0.7719345134351528, 'constant': -88.56190320269181, 'hedge ratio': 0.989743118941978, 'half life': 17.5, 'p-value of adf test': 0.014137843740083486, 'adjustment coef': -0.04063042699387341}, {'asset 1': 'SOXX', 'asset 2': 'TSM', 'res mean': 3.1961669778049844e-12, 'res std': 0.6330576297768411, 'adj rsquared': 0.7381089137188688, 'constant': -63.788490485425044, 'hedge ratio': 0.9454877129567208, 'half life': 18.5, 'p-value of adf test': 0.012213454628046662, 'adjustment coef': -0.047111844530928045}, {'asset 1': 'SOXX', 'asset 2': 'QCOM', 'res mean': 1.0750329401605249e-12, 'res std': 0.6979233907211899, 'adj rsquared': 0.6563585593649283, 'constant': 3.611600061677425, 'hedge ratio': 0.8404739313638506, 'half life': 21.5, 'p-value of adf test': 0.024179334218764822, 'adjustment coef': -0.03268068159736486}, {'asset 1': 'NVDA', 'asset 2': 'AMAT', 'res mean': -4.262819157492441e-12, 'res std': 0.7695326436655093, 'adj rsquared': 0.6308023072728064, 'constant': 234.9673320852048, 'hedge ratio': 0.02504547292057413, 'half life': 9.0, 'p-value of adf test': 0.04127079267414247, 'adjustment coef': -0.061606587391267974}]}
# {'Trading Day': '20240617', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'SOXX', 'res mean': 9.536066523324759e-12, 'res std': 0.25392535483653234, 'adj rsquared': 0.6595709004776695, 'constant': 61.70958075932852, 'hedge ratio': 0.712743463833243, 'half life': 8.5, 'p-value of adf test': 0.014171145643533582, 'adjustment coef': -0.0750994756371284}, {'asset 1': 'SMH', 'asset 2': 'TSM', 'res mean': -7.594790893050137e-13, 'res std': 0.4855700242904908, 'adj rsquared': 0.5922262606130251, 'constant': -65.70247615650678, 'hedge ratio': 0.8948461873161309, 'half life': 15.5, 'p-value of adf test': 0.02104320457022376, 'adjustment coef': -0.05822902152377431}, {'asset 1': 'NVDA', 'asset 2': 'AMAT', 'res mean': -2.9282012712008926e-12, 'res std': 0.7145759743512224, 'adj rsquared': 0.1701900579593607, 'constant': 319.3125045856597, 'hedge ratio': -0.6496163909646598, 'half life': 8.0, 'p-value of adf test': 0.04127079267414247, 'adjustment coef': -0.07436195824103944}, {'asset 1': 'TSM', 'asset 2': 'AMD', 'res mean': 5.8427382590217835e-12, 'res std': 0.6094071530996855, 'adj rsquared': 0.38940675570310584, 'constant': 48.311923410542036, 'hedge ratio': 0.6425663727519355, 'half life': 22.5, 'p-value of adf test': 0.0076185677764037335, 'adjustment coef': -0.03355678977583973}, {'asset 1': 'AMD', 'asset 2': 'ASML', 'res mean': 1.1246980554857053e-11, 'res std': 3.2101960190257466, 'adj rsquared': 0.447249861568824, 'constant': 469.40785307002454, 'hedge ratio': 3.5610005856982205, 'half life': 17.5, 'p-value of adf test': 0.03060596957765509, 'adjustment coef': -0.036871820421093805}]}
# {'Trading Day': '20240618', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'TSM', 'res mean': -9.27349365389464e-13, 'res std': 0.37230602766644905, 'adj rsquared': 0.7507536701371709, 'constant': -105.0132733789464, 'hedge ratio': 1.039794907915256, 'half life': 7.5, 'p-value of adf test': 0.021046722036890064, 'adjustment coef': -0.08433113922250095}, {'asset 1': 'SMH', 'asset 2': 'ASML', 'res mean': 1.248412655303792e-11, 'res std': 2.5705361689680206, 'adj rsquared': 0.21487285582695548, 'constant': 597.5427011047243, 'hedge ratio': 1.6172105244543342, 'half life': 17.5, 'p-value of adf test': 0.047234259399178205, 'adjustment coef': -0.04027405500260432}, {'asset 1': 'SOXX', 'asset 2': 'ASML', 'res mean': -1.2854920546837651e-11, 'res std': 2.2515916482335196, 'adj rsquared': 0.3755162950043076, 'constant': 67.23659430846317, 'hedge ratio': 3.8343864108812653, 'half life': 14.0, 'p-value of adf test': 0.047939953109785396, 'adjustment coef': -0.04179737372695795}, {'asset 1': 'NVDA', 'asset 2': 'TSM', 'res mean': -1.08687531908986e-12, 'res std': 0.464957765279398, 'adj rsquared': 0.6616231660574272, 'constant': 58.07163455933861, 'hedge ratio': 0.8825320443501272, 'half life': 9.0, 'p-value of adf test': 0.003880792450546202, 'adjustment coef': -0.07424667482537095}, {'asset 1': 'NVDA', 'asset 2': 'ASML', 'res mean': -6.327109776276092e-12, 'res std': 2.71378123758463, 'adj rsquared': 0.12409411951559984, 'constant': 946.4843040888543, 'hedge ratio': 0.6358409161599945, 'half life': 16.5, 'p-value of adf test': 0.04978453260083078, 'adjustment coef': -0.04432582494235799}, {'asset 1': 'NVDA', 'asset 2': 'AMAT', 'res mean': 4.6870313897857275e-12, 'res std': 0.6260362948419296, 'adj rsquared': 0.013099226524911634, 'constant': 237.2124773114855, 'hedge ratio': -0.0034816760880249237, 'half life': 12.0, 'p-value of adf test': 0.0467437269345585, 'adjustment coef': -0.0709801826488668}, {'asset 1': 'TSM', 'asset 2': 'ASML', 'res mean': 1.3930427182155352e-11, 'res std': 2.731889694190593, 'adj rsquared': 0.1112911225925069, 'constant': 948.6201937990008, 'hedge ratio': 0.4652531904622763, 'half life': 16.5, 'p-value of adf test': 0.04174329162906437, 'adjustment coef': -0.04292576588875313}, {'asset 1': 'TSM', 'asset 2': 'AMAT', 'res mean': -2.9343593082441475e-13, 'res std': 0.612687619068047, 'adj rsquared': 0.05429794386162384, 'constant': 201.88869543612668, 'hedge ratio': 0.2015373016206407, 'half life': 12.5, 'p-value of adf test': 0.03999640758531106, 'adjustment coef': -0.06976108738069417}]}
# {'Trading Day': '20240620', 'Coint Pairs and Params': [{'asset 1': 'NVDA', 'asset 2': 'AMAT', 'res mean': 8.137681981259868e-12, 'res std': 0.676531547291366, 'adj rsquared': 0.3423834362872225, 'constant': 176.85826743755686, 'hedge ratio': 0.48882284598056513, 'half life': 14.0, 'p-value of adf test': 0.0467437269345585, 'adjustment coef': -0.054399954872787024}]}
# {'Trading Day': '20240621', 'Coint Pairs and Params': [{'asset 1': 'SOXX', 'asset 2': 'AMD', 'res mean': 4.491541042229166e-12, 'res std': 1.428401089972164, 'adj rsquared': 0.6828489294206379, 'constant': 609.8559835938827, 'hedge ratio': -1.743612899577835, 'half life': 18.0, 'p-value of adf test': 0.045841997113953495, 'adjustment coef': -0.011665656065658035}, {'asset 1': 'AMD', 'asset 2': 'QCOM', 'res mean': 1.30178716809053e-12, 'res std': 1.1918577959655727, 'adj rsquared': 0.4450391052256506, 'constant': 316.6471643848995, 'hedge ratio': -0.5651165746120871, 'half life': 16.5, 'p-value of adf test': 0.02419959506837616, 'adjustment coef': -0.029170493444909486}]}
# {'Trading Day': '20240624', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'AMD', 'res mean': 5.912845142283447e-12, 'res std': 1.1898973725802193, 'adj rsquared': 0.5012344044168522, 'constant': 373.39045754888116, 'hedge ratio': -0.7592351728069231, 'half life': 19.0, 'p-value of adf test': 0.03982663022237266, 'adjustment coef': -0.03108249606235111}, {'asset 1': 'SMH', 'asset 2': 'ASML', 'res mean': 5.98983882436863e-12, 'res std': 2.5052123870044296, 'adj rsquared': 0.2952245964646447, 'constant': 703.337521671884, 'hedge ratio': 1.2831307973481092, 'half life': 19.5, 'p-value of adf test': 0.020424390123645976, 'adjustment coef': -0.030885551755571693}, {'asset 1': 'NVDA', 'asset 2': 'ASML', 'res mean': -1.862715110361863e-12, 'res std': 2.6538179591622812, 'adj rsquared': 0.26370207284619995, 'constant': 828.207262283411, 'hedge ratio': 1.6590469362149802, 'half life': 19.0, 'p-value of adf test': 0.024031391981388785, 'adjustment coef': -0.035274522017650335}, {'asset 1': 'TSM', 'asset 2': 'AMD', 'res mean': 6.54865335747719e-13, 'res std': 1.1104699649766958, 'adj rsquared': 0.4830865765071919, 'constant': 293.17680556970436, 'hedge ratio': -0.7250434571901487, 'half life': 18.0, 'p-value of adf test': 0.031136610819621314, 'adjustment coef': -0.029950577511055596}, {'asset 1': 'TSM', 'asset 2': 'ASML', 'res mean': 1.307427784269795e-11, 'res std': 2.8754914966694347, 'adj rsquared': 0.15204777929142604, 'constant': 814.4454189641172, 'hedge ratio': 1.3268228103276498, 'half life': 19.0, 'p-value of adf test': 0.043594651141124985, 'adjustment coef': -0.03800472142324815}, {'asset 1': 'AMD', 'asset 2': 'ASML', 'res mean': 5.270405194889278e-13, 'res std': 3.0953516591261945, 'adj rsquared': 0.05418972485922119, 'constant': 896.8456760748604, 'hedge ratio': 0.9269508880806145, 'half life': 22.5, 'p-value of adf test': 0.03204007119097763, 'adjustment coef': -0.028747968642793678}]}
# {'Trading Day': '20240625', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'ASML', 'res mean': 1.0429309837397737e-11, 'res std': 2.2717879770307343, 'adj rsquared': 0.7430070375216068, 'constant': 226.18676066919363, 'hedge ratio': 3.0569697869276324, 'half life': 16.0, 'p-value of adf test': 0.020424390123645976, 'adjustment coef': -0.04808631334294686}, {'asset 1': 'NVDA', 'asset 2': 'ASML', 'res mean': -5.504774983423069e-12, 'res std': 2.5428069415206473, 'adj rsquared': 0.6635292433637469, 'constant': 645.1482170500626, 'hedge ratio': 3.0981521256647326, 'half life': 14.5, 'p-value of adf test': 0.005926675610624618, 'adjustment coef': -0.0491228096564198}, {'asset 1': 'TSM', 'asset 2': 'ASML', 'res mean': 4.1524846239600485e-13, 'res std': 2.8875624703750455, 'adj rsquared': 0.5731127123208811, 'constant': 324.25217002340867, 'hedge ratio': 4.119499170400103, 'half life': 15.0, 'p-value of adf test': 0.03265328205072558, 'adjustment coef': -0.041483129315226644}]}
# {'Trading Day': '20240626', 'Coint Pairs and Params': [{'asset 1': 'NVDA', 'asset 2': 'TSM', 'res mean': 3.494777117269293e-12, 'res std': 0.3955665529857315, 'adj rsquared': 0.6586159552055284, 'constant': 115.8753887514953, 'hedge ratio': 0.4456470199845857, 'half life': 12.5, 'p-value of adf test': 0.03413276976598994, 'adjustment coef': -0.06104257530226698}, {'asset 1': 'ASML', 'asset 2': 'AMAT', 'res mean': -2.6207731141953565e-12, 'res std': 0.6068597126162183, 'adj rsquared': 0.6585035692086464, 'constant': 71.80471005500075, 'hedge ratio': 0.15818333343027313, 'half life': 11.0, 'p-value of adf test': 0.005268978260555032, 'adjustment coef': -0.06650543182388846}]}
# {'Trading Day': '20240627', 'Coint Pairs and Params': [{'asset 1': 'NVDA', 'asset 2': 'TSM', 'res mean': 1.2144086306365447e-12, 'res std': 0.39678249675313937, 'adj rsquared': 0.6047723333010332, 'constant': 130.76689056847005, 'hedge ratio': 0.3274534321053675, 'half life': 14.0, 'p-value of adf test': 0.0378618448697193, 'adjustment coef': -0.055189054017543614}, {'asset 1': 'NVDA', 'asset 2': 'AMAT', 'res mean': 2.4810694809182165e-13, 'res std': 0.5990300142846574, 'adj rsquared': 0.5613085912698212, 'constant': 171.88971510127254, 'hedge ratio': 0.49858133681451194, 'half life': 13.0, 'p-value of adf test': 0.03438273619892325, 'adjustment coef': -0.05475874647830036}, {'asset 1': 'TSM', 'asset 2': 'AMAT', 'res mean': -1.5252984060983483e-12, 'res std': 0.5618592577018783, 'adj rsquared': 0.618738284443138, 'constant': 18.245734762871813, 'hedge ratio': 1.2568520542470576, 'half life': 9.0, 'p-value of adf test': 0.028716886233638033, 'adjustment coef': -0.05973768906110958}, {'asset 1': 'ASML', 'asset 2': 'AMAT', 'res mean': -2.9306790612538e-12, 'res std': 0.4974243278191019, 'adj rsquared': 0.7054624460359452, 'constant': 47.197337511630934, 'hedge ratio': 0.183767243114704, 'half life': 9.0, 'p-value of adf test': 0.005268978260555032, 'adjustment coef': -0.07701409529545365}]}
# {'Trading Day': '20240628', 'Coint Pairs and Params': [{'asset 1': 'SOXX', 'asset 2': 'TSM', 'res mean': 1.4015910938980642e-12, 'res std': 0.4050032840080022, 'adj rsquared': 0.780184376835814, 'constant': -29.400801027824045, 'hedge ratio': 0.8249644294696465, 'half life': 11.5, 'p-value of adf test': 0.020568906440321978, 'adjustment coef': -0.054963835897159}, {'asset 1': 'NVDA', 'asset 2': 'TSM', 'res mean': -3.451780172233553e-12, 'res std': 0.4980962607569486, 'adj rsquared': 0.6857396746190125, 'constant': 65.32075307851267, 'hedge ratio': 0.8617001323739624, 'half life': 13.5, 'p-value of adf test': 0.0378618448697193, 'adjustment coef': -0.03788548479613424}]}
# {'Trading Day': '20240701', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'SOXX', 'res mean': 3.323153718016457e-14, 'res std': 0.2096709508206332, 'adj rsquared': 0.9660364742789269, 'constant': 0.6335805730413568, 'hedge ratio': 0.9395523493109158, 'half life': 3.5, 'p-value of adf test': 0.001336029602983059, 'adjustment coef': -0.23355997544675114}, {'asset 1': 'SMH', 'asset 2': 'QCOM', 'res mean': -1.2512839767180422e-13, 'res std': 0.5912156938830757, 'adj rsquared': 0.8563306396434583, 'constant': -120.00103800696151, 'hedge ratio': 1.2135155890217137, 'half life': 16.0, 'p-value of adf test': 0.04793102423135755, 'adjustment coef': -0.005248346005584891}, {'asset 1': 'NVDA', 'asset 2': 'TSM', 'res mean': 4.0344252155568333e-13, 'res std': 0.43837920371132144, 'adj rsquared': 0.7655599807128095, 'constant': 15.213034856912827, 'hedge ratio': 1.2704732432290218, 'half life': 7.0, 'p-value of adf test': 0.02274558155348977, 'adjustment coef': -0.06826986229897367}, {'asset 1': 'TSM', 'asset 2': 'AMAT', 'res mean': 3.987602271174695e-12, 'res std': 0.7246610553458523, 'adj rsquared': 0.8408981070928327, 'constant': -97.70737973149332, 'hedge ratio': 1.9170573535794615, 'half life': 8.0, 'p-value of adf test': 0.03841788168460504, 'adjustment coef': -0.054500016543196014}]}
# {'Trading Day': '20240702', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'AMAT', 'res mean': 3.648655167172621e-12, 'res std': 0.5396276405328158, 'adj rsquared': 0.8400130304377333, 'constant': -28.318012701436587, 'hedge ratio': 1.012543032412033, 'half life': 7.0, 'p-value of adf test': 0.03968247035990613, 'adjustment coef': -0.10896438429062713}, {'asset 1': 'SMH', 'asset 2': 'QCOM', 'res mean': -3.2514435588382186e-12, 'res std': 0.5434476774057527, 'adj rsquared': 0.9175338624220384, 'constant': -95.4555813503795, 'hedge ratio': 1.1237197802302767, 'half life': 12.0, 'p-value of adf test': 0.04793102423135755, 'adjustment coef': -0.04883492338568897}, {'asset 1': 'SOXX', 'asset 2': 'AMD', 'res mean': 1.1288519976332254e-13, 'res std': 0.6366454448222396, 'adj rsquared': 0.9413519408301181, 'constant': -245.06406216627994, 'hedge ratio': 1.647862188661041, 'half life': 11.0, 'p-value of adf test': 0.04681668647565145, 'adjustment coef': -0.042685154874018846}, {'asset 1': 'SOXX', 'asset 2': 'AMAT', 'res mean': -5.3359208789352595e-12, 'res std': 0.46872903021462076, 'adj rsquared': 0.8626295015266328, 'constant': -6.359366159332168, 'hedge ratio': 0.9831003015813591, 'half life': 5.0, 'p-value of adf test': 0.011354001912878013, 'adjustment coef': -0.1393240550857119}, {'asset 1': 'SOXX', 'asset 2': 'INTC', 'res mean': -5.535082363959914e-13, 'res std': 0.05701148970583546, 'adj rsquared': 0.8336401376296714, 'constant': 7.855106987699072, 'hedge ratio': 0.09339101743775505, 'half life': 13.5, 'p-value of adf test': 0.03369660594382699, 'adjustment coef': -0.0434448614322842}, {'asset 1': 'TSM', 'asset 2': 'AMAT', 'res mean': 4.719096908117466e-12, 'res std': 0.5878164806544335, 'adj rsquared': 0.8112784705933394, 'constant': -31.645703262194957, 'hedge ratio': 1.5384433663258528, 'half life': 4.5, 'p-value of adf test': 0.00041793545279863515, 'adjustment coef': -0.11337961136456637}, {'asset 1': 'TSM', 'asset 2': 'QCOM', 'res mean': -3.6802469903471675e-14, 'res std': 0.6476806819445109, 'adj rsquared': 0.852457251376498, 'constant': -99.31253494517982, 'hedge ratio': 1.7083841704630027, 'half life': 9.5, 'p-value of adf test': 0.03591372462218075, 'adjustment coef': -0.006946627283733898}, {'asset 1': 'TSM', 'asset 2': 'INTC', 'res mean': -5.882018518978163e-13, 'res std': 0.07571408616073724, 'adj rsquared': 0.7027210003741639, 'constant': 7.249607087607814, 'hedge ratio': 0.13579820343071677, 'half life': 16.0, 'p-value of adf test': 0.04278056283523272, 'adjustment coef': -0.014810075417233507}, {'asset 1': 'AMAT', 'asset 2': 'QCOM', 'res mean': 1.1736708471196318e-13, 'res std': 0.6509602247302076, 'adj rsquared': 0.7903548869774444, 'constant': -22.711255577564863, 'hedge ratio': 0.935272486278946, 'half life': 8.5, 'p-value of adf test': 0.006629930817036896, 'adjustment coef': -0.007361575196894915}]}
# {'Trading Day': '20240703', 'Coint Pairs and Params': [{'asset 1': 'SOXX', 'asset 2': 'AMD', 'res mean': -3.5180450383770383e-12, 'res std': 0.6059076583415263, 'adj rsquared': 0.9283130385945545, 'constant': -235.24610477040878, 'hedge ratio': 1.602259108592655, 'half life': 11.0, 'p-value of adf test': 0.010693098129386677, 'adjustment coef': -0.03183231472556259}, {'asset 1': 'TSM', 'asset 2': 'AMAT', 'res mean': 2.860911736019574e-12, 'res std': 0.4865804808679359, 'adj rsquared': 0.8186770419038096, 'constant': 50.79514544628705, 'hedge ratio': 1.076513103905297, 'half life': 5.994858611825192, 'p-value of adf test': 0.0011347952480403529, 'adjustment coef': -0.11915282767480909}, {'asset 1': 'AMD', 'asset 2': 'ASML', 'res mean': -2.427754655407363e-12, 'res std': 2.950675285947339, 'adj rsquared': 0.824961243211961, 'constant': 476.8362353409737, 'hedge ratio': 3.4950267036715457, 'half life': 18.994858611825194, 'p-value of adf test': 0.043500920941033396, 'adjustment coef': -0.0378080291067197}, {'asset 1': 'ASML', 'asset 2': 'INTC', 'res mean': -3.7322216154504334e-13, 'res std': 0.0935873868608556, 'adj rsquared': 0.40653984855833886, 'constant': 19.31805269249886, 'hedge ratio': 0.011220886716044296, 'half life': 49.452442159383025, 'p-value of adf test': 0.045946127751847594, 'adjustment coef': -0.01495493720761136}]}
# {'Trading Day': '20240705', 'Coint Pairs and Params': [{'asset 1': 'NVDA', 'asset 2': 'AMD', 'res mean': 4.623565744312931e-12, 'res std': 0.8173361636099051, 'adj rsquared': 0.40775374471575115, 'constant': 300.9515634095669, 'hedge ratio': -1.1578056670762031, 'half life': 14.785953177257525, 'p-value of adf test': 0.014358713533400895, 'adjustment coef': -0.028376497673830624}, {'asset 1': 'NVDA', 'asset 2': 'AMAT', 'res mean': -2.173880547888376e-12, 'res std': 1.013151829442175, 'adj rsquared': 0.2870814711987607, 'constant': 411.9018090814305, 'hedge ratio': -1.416072455732197, 'half life': 9.785953177257525, 'p-value of adf test': 0.02958336495454768, 'adjustment coef': -0.15901027799559675}, {'asset 1': 'NVDA', 'asset 2': 'INTC', 'res mean': -9.343993434811751e-13, 'res std': 0.08269561440443687, 'adj rsquared': 0.0406928491110716, 'constant': 33.335374349900356, 'hedge ratio': -0.01986502744598754, 'half life': 39.49498327759197, 'p-value of adf test': 0.03675831301900584, 'adjustment coef': -0.034532041051126325}, {'asset 1': 'TSM', 'asset 2': 'AMAT', 'res mean': -2.163262805602837e-11, 'res std': 0.4436063728752772, 'adj rsquared': 0.6189350015481373, 'constant': 97.92724390677917, 'hedge ratio': 0.8189505399432427, 'half life': 5.892976588628763, 'p-value of adf test': 0.0011347952480403529, 'adjustment coef': -0.19589667505177283}, {'asset 1': 'ASML', 'asset 2': 'AMAT', 'res mean': -1.7151408498578412e-12, 'res std': 0.493039347987961, 'adj rsquared': 0.6521031300750595, 'constant': 56.487933562302096, 'hedge ratio': 0.17611367742031356, 'half life': 8.488294314381271, 'p-value of adf test': 0.013066210751895221, 'adjustment coef': -0.20466313613787587}]}
# {'Trading Day': '20240708', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'AMAT', 'res mean': -1.8336028991446555e-11, 'res std': 0.5434985113855993, 'adj rsquared': 0.5385636499055989, 'constant': -126.20350578916438, 'hedge ratio': 1.3752407232480777, 'half life': 5.25, 'p-value of adf test': 0.0002629437742185127, 'adjustment coef': -0.1497655554091092}, {'asset 1': 'SOXX', 'asset 2': 'AMAT', 'res mean': -7.247535904752893e-15, 'res std': 0.5699505243083365, 'adj rsquared': 0.5153708622063686, 'constant': -47.29105039946975, 'hedge ratio': 1.1419983787463905, 'half life': 4.6000000000000005, 'p-value of adf test': 0.00020829667009450393, 'adjustment coef': -0.10734877476779404}, {'asset 1': 'TSM', 'asset 2': 'AMAT', 'res mean': -2.973010282403266e-11, 'res std': 0.5255604572253811, 'adj rsquared': 0.5263219171347528, 'constant': 91.93787098716298, 'hedge ratio': 0.8133237480968708, 'half life': 4.3, 'p-value of adf test': 0.018257628701897146, 'adjustment coef': -0.16306258343186608}, {'asset 1': 'TSM', 'asset 2': 'QCOM', 'res mean': 3.156467679824952e-12, 'res std': 0.3486131881259121, 'adj rsquared': 0.31769504767062157, 'constant': 168.3957616458357, 'hedge ratio': 0.20389918904538118, 'half life': 4.699999999999999, 'p-value of adf test': 0.005511532393349264, 'adjustment coef': -0.16780780953323537}, {'asset 1': 'AMD', 'asset 2': 'AMAT', 'res mean': 2.5569117193905793e-12, 'res std': 0.47587058540171145, 'adj rsquared': 0.560237694096405, 'constant': 276.3082879380722, 'hedge ratio': -0.19971955777391281, 'half life': 3.65, 'p-value of adf test': 0.0012974936109814387, 'adjustment coef': -0.19580740787217837}]}
# {'Trading Day': '20240709', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'QCOM', 'res mean': 5.900638382463978e-12, 'res std': 0.4327534928827849, 'adj rsquared': 0.4248040545439572, 'constant': 82.7815425294038, 'hedge ratio': 0.45105567370391636, 'half life': 13.0, 'p-value of adf test': 0.012572716920133157, 'adjustment coef': -0.017054228266949335}, {'asset 1': 'SOXX', 'asset 2': 'QCOM', 'res mean': 1.7147582499232018e-11, 'res std': 0.42105477287451676, 'adj rsquared': 0.4332567876576171, 'constant': 96.58634692245043, 'hedge ratio': 0.4250815462366537, 'half life': 16.0, 'p-value of adf test': 0.037028730624600666, 'adjustment coef': -0.022684444008149646}, {'asset 1': 'NVDA', 'asset 2': 'QCOM', 'res mean': 6.459452915572537e-12, 'res std': 0.4984106071709381, 'adj rsquared': 0.3720653948745406, 'constant': 169.8276323126231, 'hedge ratio': 0.2841107636967667, 'half life': 15.5, 'p-value of adf test': 0.02847002764070979, 'adjustment coef': -0.01932323680661852}]}
# {'Trading Day': '20240710', 'Coint Pairs and Params': []}
# {'Trading Day': '20240711', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'SOXX', 'res mean': -5.865147683764987e-12, 'res std': 0.24063817603577103, 'adj rsquared': 0.9389230976832847, 'constant': -44.45213864904463, 'hedge ratio': 1.1042255527378018, 'half life': 8.0, 'p-value of adf test': 0.02335723282945935, 'adjustment coef': -0.06776983400608338}]}
# {'Trading Day': '20240712', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'QCOM', 'res mean': -3.6821417709758795e-12, 'res std': 0.31570923112478877, 'adj rsquared': 0.4933506476425595, 'constant': 104.33479489395485, 'hedge ratio': 0.36884209891621417, 'half life': 9.5, 'p-value of adf test': 0.0026637898288120747, 'adjustment coef': -0.060539641509414654}, {'asset 1': 'SOXX', 'asset 2': 'QCOM', 'res mean': -1.207558269902037e-12, 'res std': 0.3365132504376602, 'adj rsquared': 0.4909356112477602, 'constant': 85.40377221591305, 'hedge ratio': 0.46242267383392555, 'half life': 7.5, 'p-value of adf test': 0.00022117635642441284, 'adjustment coef': -0.05817762463046032}, {'asset 1': 'AMD', 'asset 2': 'QCOM', 'res mean': -1.525881415522562e-12, 'res std': 0.6512934001262891, 'adj rsquared': 0.4114269268810666, 'constant': 88.5737765753629, 'hedge ratio': 0.6497062949056355, 'half life': 11.0, 'p-value of adf test': 0.03462213007445529, 'adjustment coef': -0.02918130287142932}, {'asset 1': 'AMAT', 'asset 2': 'QCOM', 'res mean': 1.7095658222388008e-12, 'res std': 0.35044342412534013, 'adj rsquared': 0.5541431829098508, 'constant': 81.5232302623959, 'hedge ratio': 0.49862894076095166, 'half life': 8.5, 'p-value of adf test': 0.0002807800277194582, 'adjustment coef': -0.06733309048857397}]}
# {'Trading Day': '20240715', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'AMAT', 'res mean': 1.7656076031413157e-12, 'res std': 0.4870667886329585, 'adj rsquared': 0.9453280330077238, 'constant': 25.822266723249783, 'hedge ratio': 0.8027301971733694, 'half life': 10.0, 'p-value of adf test': 0.0060374659702949795, 'adjustment coef': -0.07093525768690843}, {'asset 1': 'SMH', 'asset 2': 'INTC', 'res mean': -2.7760358114811915e-13, 'res std': 0.11555227857197138, 'adj rsquared': 0.9272784260554456, 'constant': -7.722868335032768, 'hedge ratio': 0.15217730736025487, 'half life': 16.0, 'p-value of adf test': 0.02028591255018967, 'adjustment coef': -0.048622150839974856}, {'asset 1': 'SOXX', 'asset 2': 'AMAT', 'res mean': -3.1140719632579323e-12, 'res std': 0.4932286232021817, 'adj rsquared': 0.9479144297609121, 'constant': 2.322993996078978, 'hedge ratio': 0.9378315932011143, 'half life': 8.5, 'p-value of adf test': 0.0064522938976777355, 'adjustment coef': -0.06921741118973647}, {'asset 1': 'SOXX', 'asset 2': 'QCOM', 'res mean': -5.046857518792445e-12, 'res std': 0.30136857076910784, 'adj rsquared': 0.9703553861136067, 'constant': 6.635086978123297, 'hedge ratio': 0.7553048740679709, 'half life': 7.5, 'p-value of adf test': 0.0012640909202433178, 'adjustment coef': -0.08284396609819226}, {'asset 1': 'SOXX', 'asset 2': 'INTC', 'res mean': -3.811697396462804e-13, 'res std': 0.12089770789106499, 'adj rsquared': 0.9203545881665554, 'constant': -10.302771047270577, 'hedge ratio': 0.1705522752989158, 'half life': 17.5, 'p-value of adf test': 0.009137615194325472, 'adjustment coef': -0.04679127393645098}, {'asset 1': 'AMD', 'asset 2': 'AMAT', 'res mean': -1.2661871551244985e-12, 'res std': 0.9515274819204322, 'adj rsquared': 0.8440950556432778, 'constant': 23.326001409488, 'hedge ratio': 1.2287087411473023, 'half life': 11.5, 'p-value of adf test': 0.026918011038682604, 'adjustment coef': -0.043024285343222765}, {'asset 1': 'AMD', 'asset 2': 'QCOM', 'res mean': -8.199663170671557e-13, 'res std': 0.6904273510450778, 'adj rsquared': 0.8726154184553075, 'constant': 21.462816108663574, 'hedge ratio': 1.0011847986616913, 'half life': 11.0, 'p-value of adf test': 0.03462213007445529, 'adjustment coef': -0.027802889699758748}, {'asset 1': 'AMAT', 'asset 2': 'QCOM', 'res mean': 2.937893802878441e-12, 'res std': 0.430659104849788, 'adj rsquared': 0.9324095105637906, 'constant': 14.372132515599063, 'hedge ratio': 0.7660708437984343, 'half life': 9.0, 'p-value of adf test': 0.006345923782054949, 'adjustment coef': -0.04945145771920059}, {'asset 1': 'AMAT', 'asset 2': 'INTC', 'res mean': 6.075413676416457e-13, 'res std': 0.1613713569422069, 'adj rsquared': 0.8548945962691904, 'constant': -9.769701825214062, 'hedge ratio': 0.17840901452958868, 'half life': 15.5, 'p-value of adf test': 0.005889896408744135, 'adjustment coef': -0.04233043683818994}, {'asset 1': 'QCOM', 'asset 2': 'INTC', 'res mean': 2.2874010378123226e-13, 'res std': 0.11557314986351042, 'adj rsquared': 0.9249571641297174, 'constant': -14.437784054416618, 'hedge ratio': 0.23908168820694786, 'half life': 10.0, 'p-value of adf test': 0.017033081189527316, 'adjustment coef': -0.07399008163240323}]}
# {'Trading Day': '20240716', 'Coint Pairs and Params': [{'asset 1': 'TSM', 'asset 2': 'AMAT', 'res mean': -3.4330145563916843e-12, 'res std': 0.6947735577721167, 'adj rsquared': 0.5438827351784745, 'constant': 217.79066513029903, 'hedge ratio': 0.15006424457768103, 'half life': 10.0, 'p-value of adf test': 0.005501572724532301, 'adjustment coef': -0.06645502851214517}]}
# {'Trading Day': '20240717', 'Coint Pairs and Params': [{'asset 1': 'NVDA', 'asset 2': 'AMD', 'res mean': 5.946696126976838e-14, 'res std': 0.5049801251707556, 'adj rsquared': 0.8211174392742113, 'constant': 16.57954409674098, 'hedge ratio': 1.275544387733304, 'half life': 13.5, 'p-value of adf test': 0.007423304596724349, 'adjustment coef': -0.055440793531914445}]}
# {'Trading Day': '20240718', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'AMAT', 'res mean': 5.444761450818101e-12, 'res std': 1.154249558568634, 'adj rsquared': 0.7258933987560082, 'constant': -108.48550025076082, 'hedge ratio': 1.29817516929478, 'half life': 6.0, 'p-value of adf test': 0.00045818456066281667, 'adjustment coef': -0.1151559676871311}, {'asset 1': 'NVDA', 'asset 2': 'AMD', 'res mean': -5.757218064107478e-14, 'res std': 0.7589691721716254, 'adj rsquared': 0.9055172647602809, 'constant': -82.1170516351481, 'hedge ratio': 2.071237610603939, 'half life': 14.0, 'p-value of adf test': 0.045635161590141145, 'adjustment coef': -0.03325819663364651}, {'asset 1': 'NVDA', 'asset 2': 'ASML', 'res mean': -2.955712028405964e-12, 'res std': 3.4550232177246825, 'adj rsquared': 0.867561288759675, 'constant': -23.494055775155346, 'hedge ratio': 8.550127246407977, 'half life': 10.5, 'p-value of adf test': 0.03392816029547159, 'adjustment coef': -0.04261574708532212}]}
# {'Trading Day': '20240719', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'ASML', 'res mean': 2.2683439172583474e-12, 'res std': 3.392693250522095, 'adj rsquared': 0.9395710382480935, 'constant': -553.3636929932405, 'hedge ratio': 5.798384290325812, 'half life': 10.0, 'p-value of adf test': 0.002109390226058946, 'adjustment coef': -0.05773360373912694}, {'asset 1': 'SMH', 'asset 2': 'QCOM', 'res mean': 1.4405798491423365e-12, 'res std': 0.5527622014518474, 'adj rsquared': 0.9390004144261066, 'constant': -53.337351819950015, 'hedge ratio': 0.9552696261187239, 'half life': 11.0, 'p-value of adf test': 0.04482152718642181, 'adjustment coef': -0.05234787554721847}, {'asset 1': 'SOXX', 'asset 2': 'ASML', 'res mean': 9.176131080051002e-12, 'res std': 4.0511596231986156, 'adj rsquared': 0.9119162183963394, 'constant': -669.2313175825288, 'hedge ratio': 6.515719237755798, 'half life': 12.0, 'p-value of adf test': 0.03663717176996046, 'adjustment coef': -0.039431875208942146}, {'asset 1': 'NVDA', 'asset 2': 'ASML', 'res mean': 5.619627839993112e-12, 'res std': 4.240385955653757, 'adj rsquared': 0.9057361222509245, 'constant': -361.6578336084076, 'hedge ratio': 10.936261992579196, 'half life': 9.5, 'p-value of adf test': 0.0067452287746098405, 'adjustment coef': -0.04219305768859437}, {'asset 1': 'NVDA', 'asset 2': 'QCOM', 'res mean': 1.9288866800100855e-12, 'res std': 0.7667524417596941, 'adj rsquared': 0.8864047802522999, 'constant': -19.06843474015865, 'hedge ratio': 1.7800205927325137, 'half life': 10.0, 'p-value of adf test': 0.005196913634776264, 'adjustment coef': -0.03735720039919398}, {'asset 1': 'AMD', 'asset 2': 'QCOM', 'res mean': 3.152987842324178e-12, 'res std': 0.6319050736633265, 'adj rsquared': 0.9215320610483351, 'constant': 80.02984929763613, 'hedge ratio': 0.7005726031482472, 'half life': 11.0, 'p-value of adf test': 0.0028168093981755936, 'adjustment coef': -0.053866559385813625}, {'asset 1': 'ASML', 'asset 2': 'QCOM', 'res mean': -2.7496910731245477e-12, 'res std': 0.6636244793638668, 'adj rsquared': 0.9083193157102882, 'constant': 45.986600591260625, 'hedge ratio': 0.15620327235511317, 'half life': 10.0, 'p-value of adf test': 0.006672887174520854, 'adjustment coef': -0.058921242736666234}, {'asset 1': 'AMAT', 'asset 2': 'QCOM', 'res mean': 1.9721022535799045e-12, 'res std': 0.6062516680877035, 'adj rsquared': 0.9308604941006045, 'constant': 28.5211633406051, 'hedge ratio': 0.7374243819006397, 'half life': 9.5, 'p-value of adf test': 0.025514354728443323, 'adjustment coef': -0.08282478626416029}]}
# {'Trading Day': '20240722', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'NVDA', 'res mean': 1.8350768198452456e-12, 'res std': 0.2737594491794184, 'adj rsquared': 0.9032802540580753, 'constant': 18.16484409351907, 'hedge ratio': 0.39960113354919946, 'half life': 9.0, 'p-value of adf test': 0.03055718978911153, 'adjustment coef': -0.07374420493591945}, {'asset 1': 'SMH', 'asset 2': 'AMAT', 'res mean': 3.2229125351407746e-12, 'res std': 0.4950286090979971, 'adj rsquared': 0.9440916584259222, 'constant': -15.28947897597105, 'hedge ratio': 0.9152317478202148, 'half life': 5.5, 'p-value of adf test': 0.01126009307363128, 'adjustment coef': -0.15060922729241033}, {'asset 1': 'SOXX', 'asset 2': 'AMAT', 'res mean': -1.2148823257937179e-12, 'res std': 0.5423009230925512, 'adj rsquared': 0.9337101526543179, 'constant': -20.139904458914103, 'hedge ratio': 0.9771268975764882, 'half life': 6.0, 'p-value of adf test': 0.010117325065851078, 'adjustment coef': -0.12334240319831481}, {'asset 1': 'NVDA', 'asset 2': 'TSM', 'res mean': 2.453558723713146e-12, 'res std': 0.7783695178632639, 'adj rsquared': 0.8837972612537164, 'constant': -107.40049008361542, 'hedge ratio': 2.314086843095738, 'half life': 7.0, 'p-value of adf test': 0.001066805169597006, 'adjustment coef': -0.06435649133017764}, {'asset 1': 'NVDA', 'asset 2': 'AMAT', 'res mean': -1.25212205276535e-12, 'res std': 0.8223174489066349, 'adj rsquared': 0.842230587562451, 'constant': -34.631920679262194, 'hedge ratio': 2.1041258238167613, 'half life': 8.5, 'p-value of adf test': 0.006589947158032942, 'adjustment coef': -0.06941657304112385}, {'asset 1': 'NVDA', 'asset 2': 'QCOM', 'res mean': 1.3089290335371445e-12, 'res std': 0.606621731437615, 'adj rsquared': 0.8534428927913477, 'constant': -7.139392257177548, 'hedge ratio': 1.6515768089827358, 'half life': 10.0, 'p-value of adf test': 0.008892804264294223, 'adjustment coef': -0.045443908118221216}, {'asset 1': 'TSM', 'asset 2': 'AMAT', 'res mean': 3.2111065943004526e-12, 'res std': 0.6730119232240888, 'adj rsquared': 0.8991974156501525, 'constant': 67.41377574910072, 'hedge ratio': 0.8844490278509508, 'half life': 5.5, 'p-value of adf test': 0.0005238594259104255, 'adjustment coef': -0.1102413137855405}, {'asset 1': 'AMD', 'asset 2': 'AMAT', 'res mean': 2.1376040538784883e-12, 'res std': 0.6847638350704588, 'adj rsquared': 0.8932302719395342, 'constant': 56.97370371061829, 'hedge ratio': 1.027969694202635, 'half life': 8.5, 'p-value of adf test': 0.014505087877949295, 'adjustment coef': -0.10727966672238859}, {'asset 1': 'AMD', 'asset 2': 'INTC', 'res mean': -6.280742308006619e-13, 'res std': 0.28887209091005245, 'adj rsquared': 0.764606655582825, 'constant': 0.14419872838185555, 'hedge ratio': 0.22578097455861126, 'half life': 15.0, 'p-value of adf test': 0.0363450072461008, 'adjustment coef': -0.0033933776867581867}, {'asset 1': 'ASML', 'asset 2': 'AMAT', 'res mean': -5.982405454209909e-13, 'res std': 0.7777656628574612, 'adj rsquared': 0.8502199861414103, 'constant': 36.35037737365614, 'hedge ratio': 0.195826557803078, 'half life': 9.0, 'p-value of adf test': 0.005279577092745956, 'adjustment coef': -0.0851636682456236}, {'asset 1': 'AMAT', 'asset 2': 'QCOM', 'res mean': 9.960351631796071e-13, 'res std': 0.44627622133768097, 'adj rsquared': 0.9130861975450788, 'constant': 30.227996693382707, 'hedge ratio': 0.7386935912710554, 'half life': 5.5, 'p-value of adf test': 0.0273458731434173, 'adjustment coef': -0.09789816620809641}]}
# {'Trading Day': '20240723', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'AMAT', 'res mean': 2.9639105984339645e-12, 'res std': 0.6842456985927448, 'adj rsquared': 0.8885433483140315, 'constant': -100.7790170905154, 'hedge ratio': 1.2525700226771845, 'half life': 12.0, 'p-value of adf test': 0.02488567084846339, 'adjustment coef': -0.0934650775217474}, {'asset 1': 'SOXX', 'asset 2': 'NVDA', 'res mean': -2.6503790615186937e-12, 'res std': 0.3125126513848346, 'adj rsquared': 0.826701346370927, 'constant': -1.5773590515732785, 'hedge ratio': 0.5062676471125108, 'half life': 13.0, 'p-value of adf test': 0.04249542152715756, 'adjustment coef': -0.04382082538137852}, {'asset 1': 'SOXX', 'asset 2': 'AMAT', 'res mean': 2.358382435210306e-12, 'res std': 0.728321485212582, 'adj rsquared': 0.8737714558194762, 'constant': -115.83128827514263, 'hedge ratio': 1.3755540873818821, 'half life': 10.5, 'p-value of adf test': 0.008266838474406468, 'adjustment coef': -0.07313677379852948}, {'asset 1': 'ASML', 'asset 2': 'AMAT', 'res mean': -2.2110632413293786e-13, 'res std': 1.0206812549730606, 'adj rsquared': 0.7516897488038772, 'constant': -132.02272742147858, 'hedge ratio': 0.3764432727603106, 'half life': 12.5, 'p-value of adf test': 0.02697192250281986, 'adjustment coef': -0.04821967342753324}, {'asset 1': 'AMAT', 'asset 2': 'QCOM', 'res mean': 5.9225012358719815e-12, 'res std': 0.545327189214836, 'adj rsquared': 0.8774352603635229, 'constant': 31.87830506231701, 'hedge ratio': 0.7333330416121605, 'half life': 11.0, 'p-value of adf test': 0.03397775590433842, 'adjustment coef': -0.055127568859923884}]}
# {'Trading Day': '20240724', 'Coint Pairs and Params': [{'asset 1': 'ASML', 'asset 2': 'AMAT', 'res mean': 1.758647928139768e-12, 'res std': 1.0925895871007745, 'adj rsquared': 0.7283670605467323, 'constant': -255.1158774117848, 'hedge ratio': 0.5089691426993943, 'half life': 13.0, 'p-value of adf test': 0.034936383352401554, 'adjustment coef': -0.025372205201295378}, {'asset 1': 'AMAT', 'asset 2': 'INTC', 'res mean': -1.5739432549311553e-13, 'res std': 0.0765786859862584, 'adj rsquared': 0.3839709292711118, 'constant': 31.136863010440436, 'hedge ratio': 0.00849667253592231, 'half life': 9.0, 'p-value of adf test': 0.04674859158686971, 'adjustment coef': -0.0687288597387703}]}
# {'Trading Day': '20240725', 'Coint Pairs and Params': [{'asset 1': 'SOXX', 'asset 2': 'INTC', 'res mean': 4.3412339250491457e-13, 'res std': 0.07365822475819274, 'adj rsquared': 0.708200241314271, 'constant': 4.38730820723362, 'hedge ratio': 0.11764301482622677, 'half life': 10.0, 'p-value of adf test': 0.010286459579283572, 'adjustment coef': -0.060084402280486435}, {'asset 1': 'NVDA', 'asset 2': 'INTC', 'res mean': 3.057793334776831e-13, 'res std': 0.09896169725873144, 'adj rsquared': 0.3757060973662186, 'constant': 23.411656813920725, 'hedge ratio': 0.07889319271510958, 'half life': 18.0, 'p-value of adf test': 0.043910495972528836, 'adjustment coef': -0.032688647133557305}, {'asset 1': 'AMD', 'asset 2': 'INTC', 'res mean': 3.463440360717821e-13, 'res std': 0.08648283613656259, 'adj rsquared': 0.475543618849208, 'constant': 24.797749049471022, 'hedge ratio': 0.053481631403706764, 'half life': 11.5, 'p-value of adf test': 0.02183703535831543, 'adjustment coef': -0.03813186331505392}, {'asset 1': 'ASML', 'asset 2': 'INTC', 'res mean': -8.260332588878765e-13, 'res std': 0.07517070044743819, 'adj rsquared': 0.6362015256574747, 'constant': 15.39097555104521, 'hedge ratio': 0.018791841996300025, 'half life': 11.5, 'p-value of adf test': 0.015872045834425794, 'adjustment coef': -0.06270975879517826}, {'asset 1': 'QCOM', 'asset 2': 'INTC', 'res mean': 6.620345297610933e-13, 'res std': 0.07286769567636087, 'adj rsquared': 0.7069583979373708, 'constant': 22.70259312594016, 'hedge ratio': 0.0528007509651036, 'half life': 13.0, 'p-value of adf test': 0.0007642356347453666, 'adjustment coef': -0.05840628422491111}]}
# {'Trading Day': '20240726', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'NVDA', 'res mean': 9.025532458158873e-13, 'res std': 0.27590156787567155, 'adj rsquared': 0.9554354000126178, 'constant': -48.44233618479471, 'hedge ratio': 0.6790581330209747, 'half life': 8.5, 'p-value of adf test': 0.0074489849516215685, 'adjustment coef': -0.0797427082166128}, {'asset 1': 'SMH', 'asset 2': 'INTC', 'res mean': 2.8326059446743994e-14, 'res std': 0.07863182331172311, 'adj rsquared': 0.7773311729921164, 'constant': 13.068078427705025, 'hedge ratio': 0.0771041605044966, 'half life': 15.5, 'p-value of adf test': 0.021692292389701866, 'adjustment coef': -0.05456369256687946}, {'asset 1': 'SOXX', 'asset 2': 'NVDA', 'res mean': -7.821071425822969e-13, 'res std': 0.40681028627172067, 'adj rsquared': 0.9047710849259034, 'constant': -62.07701504789666, 'hedge ratio': 0.7715771615662408, 'half life': 12.0, 'p-value of adf test': 0.025095056845575305, 'adjustment coef': -0.05325261064489399}, {'asset 1': 'SOXX', 'asset 2': 'INTC', 'res mean': 9.130018678404621e-14, 'res std': 0.07451605771801281, 'adj rsquared': 0.8035106689750375, 'constant': 10.454180275887413, 'hedge ratio': 0.09212617500339162, 'half life': 14.5, 'p-value of adf test': 0.00589947235868007, 'adjustment coef': -0.05936697787651497}, {'asset 1': 'ASML', 'asset 2': 'QCOM', 'res mean': 4.502654659378234e-12, 'res std': 0.6314890334771652, 'adj rsquared': 0.8193729223632591, 'constant': -32.77801654448731, 'hedge ratio': 0.23956588879472546, 'half life': 10.5, 'p-value of adf test': 0.010028219040545665, 'adjustment coef': -0.04839218131468405}, {'asset 1': 'ASML', 'asset 2': 'INTC', 'res mean': 1.3116801092576518e-13, 'res std': 0.08479601397334849, 'adj rsquared': 0.7027701852871275, 'constant': 15.705202092383459, 'hedge ratio': 0.018087033511538286, 'half life': 14.0, 'p-value of adf test': 0.0168097122165729, 'adjustment coef': -0.04303564602946304}, {'asset 1': 'QCOM', 'asset 2': 'INTC', 'res mean': 1.5123173368873468e-13, 'res std': 0.0830172107241382, 'adj rsquared': 0.7418937641391278, 'constant': 18.28508698757989, 'hedge ratio': 0.07483170438783476, 'half life': 13.5, 'p-value of adf test': 0.019070576584778388, 'adjustment coef': -0.05359439238411631}]}
# {'Trading Day': '20240729', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'INTC', 'res mean': 3.581135388230905e-13, 'res std': 0.06604154525802905, 'adj rsquared': 0.7884472627776343, 'constant': 6.43797430229918, 'hedge ratio': 0.10407370445970542, 'half life': 8.0, 'p-value of adf test': 0.021692292389701866, 'adjustment coef': -0.07642763900404836}, {'asset 1': 'SOXX', 'asset 2': 'QCOM', 'res mean': 2.209059146433645e-12, 'res std': 0.47038282269465115, 'adj rsquared': 0.7208667578045459, 'constant': 36.79399456226333, 'hedge ratio': 0.6236650740411595, 'half life': 10.0, 'p-value of adf test': 0.04201422394637689, 'adjustment coef': -0.08814583715129166}, {'asset 1': 'SOXX', 'asset 2': 'INTC', 'res mean': -4.1018356802315115e-13, 'res std': 0.06850977512139877, 'adj rsquared': 0.7844193216036169, 'constant': 2.9352761514334063, 'hedge ratio': 0.12473421884185956, 'half life': 6.0, 'p-value of adf test': 0.00589947235868007, 'adjustment coef': -0.07833120637549584}]}
# ...
# {'Trading Day': '20240813', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'SOXX', 'res mean': -2.8122533541662823e-13, 'res std': 0.22763413511115133, 'adj rsquared': 0.9541465579235174, 'constant': 22.657161386423642, 'hedge ratio': 0.841844781004677, 'half life': 5.997432605905006, 'p-value of adf test': 0.03223716037053404, 'adjustment coef': -0.11177288897473224}, {'asset 1': 'SMH', 'asset 2': 'AMD', 'res mean': -2.2427975893527536e-12, 'res std': 0.41788064195911867, 'adj rsquared': 0.8908957845992851, 'constant': -44.21019352099579, 'hedge ratio': 0.7962304828816047, 'half life': 12.001283697047498, 'p-value of adf test': 0.014203783408102907, 'adjustment coef': -0.032909078039629905}, {'asset 1': 'SMH', 'asset 2': 'ASML', 'res mean': 2.4703026103081162e-11, 'res std': 1.5931307099019945, 'adj rsquared': 0.48659498313420363, 'constant': 446.4133769841635, 'hedge ratio': 1.8376459065830524, 'half life': 10.498074454428755, 'p-value of adf test': 0.007452091268200704, 'adjustment coef': -0.04972689778219135}, {'asset 1': 'SMH', 'asset 2': 'AMAT', 'res mean': 1.0721442276275383e-12, 'res std': 0.44631678316289514, 'adj rsquared': 0.8610864858252241, 'constant': 22.98223457967952, 'hedge ratio': 0.7480787398818218, 'half life': 8.994865211810012, 'p-value of adf test': 0.02934741807507046, 'adjustment coef': -0.09243633115442611}, {'asset 1': 'SOXX', 'asset 2': 'ASML', 'res mean': -1.5186314051955896e-11, 'res std': 1.5678764938546688, 'adj rsquared': 0.5279259325393416, 'constant': 435.97750164242535, 'hedge ratio': 1.9976730362786816, 'half life': 11.498074454428755, 'p-value of adf test': 0.020871064521775746, 'adjustment coef': -0.048393360191180554}, {'asset 1': 'NVDA', 'asset 2': 'AMD', 'res mean': 6.547938628337108e-13, 'res std': 0.5109747236881996, 'adj rsquared': 0.8350132032706084, 'constant': 31.234086189744104, 'hedge ratio': 0.9832216608808539, 'half life': 14.993581514762516, 'p-value of adf test': 0.019444733384692974, 'adjustment coef': -0.03262891501431501}, {'asset 1': 'NVDA', 'asset 2': 'ASML', 'res mean': 2.539346567851244e-13, 'res std': 1.7675301709835713, 'adj rsquared': 0.4470097711701051, 'constant': 562.7459544401318, 'hedge ratio': 2.818174047247225, 'half life': 8.997432605905006, 'p-value of adf test': 0.0015958389143651472, 'adjustment coef': -0.051303444740492546}, {'asset 1': 'TSM', 'asset 2': 'INTC', 'res mean': -3.747953309852426e-13, 'res std': 0.10067909480368888, 'adj rsquared': 0.6514200558385757, 'constant': 13.148068689961576, 'hedge ratio': 0.04035261269950474, 'half life': 16.50064184852375, 'p-value of adf test': 0.04586854862800463, 'adjustment coef': -0.013358664939830841}, {'asset 1': 'AMD', 'asset 2': 'ASML', 'res mean': -2.9393666220167767e-12, 'res std': 1.9494301710009685, 'adj rsquared': 0.43110086399035125, 'constant': 614.5546837021577, 'hedge ratio': 1.8165378801864618, 'half life': 11.500641848523749, 'p-value of adf test': 0.006210512429406577, 'adjustment coef': -0.03273053168875957}, {'asset 1': 'AMD', 'asset 2': 'AMAT', 'res mean': -2.1325403288923164e-13, 'res std': 0.6305630453300455, 'adj rsquared': 0.7248408388132228, 'constant': 77.99404319195727, 'hedge ratio': 0.8405678126847167, 'half life': 14.492939666238767, 'p-value of adf test': 0.013280895533764879, 'adjustment coef': -0.06095035301703624}]}
# {'Trading Day': '20240814', 'Coint Pairs and Params': [{'asset 1': 'AMD', 'asset 2': 'ASML', 'res mean': 2.5408059624304664e-13, 'res std': 1.6421436831740914, 'adj rsquared': 0.34925033840288217, 'constant': 720.504210488876, 'hedge ratio': 1.013701464612158, 'half life': 12.501925545571245, 'p-value of adf test': 0.01870711192996338, 'adjustment coef': -0.027920842004971167}]}
# {'Trading Day': '20240815', 'Coint Pairs and Params': []}
# {'Trading Day': '20240816', 'Coint Pairs and Params': []}
# {'Trading Day': '20240819', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'INTC', 'res mean': 1.3555424589074579e-13, 'res std': 0.04684813901903455, 'adj rsquared': 0.9011121711887914, 'constant': 1.5101149932886127, 'hedge ratio': 0.0778742274564048, 'half life': 8.0, 'p-value of adf test': 0.004087721459410189, 'adjustment coef': -0.06830336901349786}, {'asset 1': 'SOXX', 'asset 2': 'INTC', 'res mean': 6.920185222579442e-13, 'res std': 0.05096167181784582, 'adj rsquared': 0.865817135419666, 'constant': 3.189843438956646, 'hedge ratio': 0.07559248105596832, 'half life': 8.5, 'p-value of adf test': 0.0130379903021547, 'adjustment coef': -0.06014743481902011}, {'asset 1': 'ASML', 'asset 2': 'INTC', 'res mean': -2.24540614022445e-13, 'res std': 0.06293462783225909, 'adj rsquared': 0.7933388295956956, 'constant': 0.35467170669892933, 'hedge ratio': 0.02210566765459486, 'half life': 12.0, 'p-value of adf test': 0.03050466728609703, 'adjustment coef': -0.049246551767817726}]}
# {'Trading Day': '20240820', 'Coint Pairs and Params': []}
# {'Trading Day': '20240821', 'Coint Pairs and Params': []}
# {'Trading Day': '20240822', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'NVDA', 'res mean': 3.5061458010414543e-12, 'res std': 0.19402925678151123, 'adj rsquared': 0.9464654185315464, 'constant': -36.69586979403612, 'hedge ratio': 0.6609909079562364, 'half life': 8.0, 'p-value of adf test': 0.006342090754214973, 'adjustment coef': -0.08150120715061523}, {'asset 1': 'SMH', 'asset 2': 'TSM', 'res mean': 4.258300834454787e-12, 'res std': 0.3057511338452175, 'adj rsquared': 0.925065853878346, 'constant': -45.83033345274747, 'hedge ratio': 0.8744894471539646, 'half life': 12.0, 'p-value of adf test': 0.035909707666788714, 'adjustment coef': -0.030825480194521564}, {'asset 1': 'SMH', 'asset 2': 'AMAT', 'res mean': 2.512296923202648e-12, 'res std': 0.3455016123913714, 'adj rsquared': 0.8872106540554001, 'constant': -13.523916596713093, 'hedge ratio': 0.888601468418181, 'half life': 8.5, 'p-value of adf test': 0.015455920126848136, 'adjustment coef': -0.08634683555881567}, {'asset 1': 'NVDA', 'asset 2': 'AMD', 'res mean': 3.1374287783154825e-12, 'res std': 0.692564263636517, 'adj rsquared': 0.15231453453242516, 'constant': 137.9383999932642, 'hedge ratio': 0.15117351907030083, 'half life': 20.5, 'p-value of adf test': 0.045003264855875205, 'adjustment coef': -0.02851062735523578}, {'asset 1': 'NVDA', 'asset 2': 'AMAT', 'res mean': -3.618484429469577e-12, 'res std': 0.4481115874614491, 'adj rsquared': 0.8201683387238501, 'constant': 43.68007599679304, 'hedge ratio': 1.2824114180113906, 'half life': 10.5, 'p-value of adf test': 0.007225294247718986, 'adjustment coef': -0.0699980835613352}]}
# {'Trading Day': '20240823', 'Coint Pairs and Params': [{'asset 1': 'SOXX', 'asset 2': 'QCOM', 'res mean': -2.9972514498811695e-12, 'res std': 0.2805088678599488, 'adj rsquared': 0.8935247162699674, 'constant': -0.11013202352415163, 'hedge ratio': 0.7400130330138424, 'half life': 12.5, 'p-value of adf test': 0.027140997928137754, 'adjustment coef': -0.04968637601008029}]}
# {'Trading Day': '20240826', 'Coint Pairs and Params': [{'asset 1': 'AMD', 'asset 2': 'QCOM', 'res mean': -2.2534771769409044e-12, 'res std': 0.3212497178550856, 'adj rsquared': 0.908014325207489, 'constant': 33.31222527230656, 'hedge ratio': 0.8970054659645679, 'half life': 11.5, 'p-value of adf test': 0.002481255187747369, 'adjustment coef': -0.055344027194518974}]}
# {'Trading Day': '20240827', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'TSM', 'res mean': -7.61413951831622e-12, 'res std': 0.31752116343433634, 'adj rsquared': 0.8070070071933468, 'constant': 65.01371640494193, 'hedge ratio': 0.42653558394106456, 'half life': 15.5, 'p-value of adf test': 0.03593549890416163, 'adjustment coef': -0.02943245605996693}, {'asset 1': 'SOXX', 'asset 2': 'AMD', 'res mean': 8.726922318694562e-13, 'res std': 0.49535758080235615, 'adj rsquared': 0.8847139235543392, 'constant': -14.546546104600772, 'hedge ratio': 0.7269277135251575, 'half life': 20.0, 'p-value of adf test': 0.02362609925207737, 'adjustment coef': -0.03784116960478385}, {'asset 1': 'SOXX', 'asset 2': 'INTC', 'res mean': -2.5141825943090876e-13, 'res std': 0.05669059633496126, 'adj rsquared': 0.9160432643050953, 'constant': -5.782186455085412, 'hedge ratio': 0.11345787731855728, 'half life': 12.0, 'p-value of adf test': 0.0448597975542473, 'adjustment coef': -0.04948754700350258}, {'asset 1': 'NVDA', 'asset 2': 'TSM', 'res mean': 6.656874481846806e-13, 'res std': 0.3861824489187877, 'adj rsquared': 0.7568822879669203, 'constant': 112.90184554740424, 'hedge ratio': 0.44908977340341927, 'half life': 16.0, 'p-value of adf test': 0.02287564618786208, 'adjustment coef': -0.034412462495561756}, {'asset 1': 'AMD', 'asset 2': 'ASML', 'res mean': 3.132276432528996e-11, 'res std': 2.6181694866163565, 'adj rsquared': 0.43345453453493465, 'constant': 622.6104345504335, 'hedge ratio': 1.850516643527774, 'half life': 21.5, 'p-value of adf test': 0.021546126677748776, 'adjustment coef': -0.017021669722089895}]}
# {'Trading Day': '20240828', 'Coint Pairs and Params': [{'asset 1': 'SOXX', 'asset 2': 'AMD', 'res mean': -3.507311819889881e-12, 'res std': 0.5930929917159596, 'adj rsquared': 0.43972621533435324, 'constant': 45.34720138000597, 'hedge ratio': 0.46057464222369393, 'half life': 23.0, 'p-value of adf test': 0.026977333624617662, 'adjustment coef': -0.03443530468071608}, {'asset 1': 'NVDA', 'asset 2': 'AMD', 'res mean': 5.208096062676468e-13, 'res std': 0.5005823778936556, 'adj rsquared': 0.4651385967337655, 'constant': 76.03181977013435, 'hedge ratio': 0.5882344442260995, 'half life': 13.5, 'p-value of adf test': 0.018881643519827296, 'adjustment coef': -0.042172278564143316}, {'asset 1': 'AMAT', 'asset 2': 'INTC', 'res mean': -1.7656986983638488e-13, 'res std': 0.046957891497315274, 'adj rsquared': 0.707766331044877, 'constant': 6.931226091442176, 'hedge ratio': 0.0673247275127685, 'half life': 11.0, 'p-value of adf test': 0.005171706776411388, 'adjustment coef': -0.061290681289905106}]}
# {'Trading Day': '20240829', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'SOXX', 'res mean': 4.504549440006929e-12, 'res std': 0.15352448352655157, 'adj rsquared': 0.9872067167536045, 'constant': 7.767491277342245, 'hedge ratio': 0.9065157570065916, 'half life': 3.0, 'p-value of adf test': 0.0018187222316474684, 'adjustment coef': -0.37583664640532544}, {'asset 1': 'SMH', 'asset 2': 'AMD', 'res mean': 4.536141263181493e-12, 'res std': 0.37944205152291005, 'adj rsquared': 0.4968376674786448, 'constant': 42.884412481397995, 'hedge ratio': 0.4380786289917671, 'half life': 12.5, 'p-value of adf test': 0.011432830201579206, 'adjustment coef': -0.04937293367480707}, {'asset 1': 'SOXX', 'asset 2': 'NVDA', 'res mean': -1.2197650297215046e-13, 'res std': 0.329421844858367, 'adj rsquared': 0.9142791412723523, 'constant': -61.5239856135952, 'hedge ratio': 0.8266382270464853, 'half life': 12.0, 'p-value of adf test': 0.047992862978384405, 'adjustment coef': -0.06358995571615414}, {'asset 1': 'SOXX', 'asset 2': 'AMD', 'res mean': -6.042528301081917e-13, 'res std': 0.4063542126859544, 'adj rsquared': 0.48877342925358414, 'constant': 38.46205307973713, 'hedge ratio': 0.4860237849512495, 'half life': 8.5, 'p-value of adf test': 0.01117621156976946, 'adjustment coef': -0.05701623557102377}, {'asset 1': 'NVDA', 'asset 2': 'AMD', 'res mean': 1.1647070772223509e-12, 'res std': 0.39722195704619345, 'adj rsquared': 0.48574007509347517, 'constant': 76.38395059360789, 'hedge ratio': 0.5747994477006314, 'half life': 10.5, 'p-value of adf test': 0.009750648717828981, 'adjustment coef': -0.050688781352813364}, {'asset 1': 'AMAT', 'asset 2': 'INTC', 'res mean': -4.2888997197037375e-13, 'res std': 0.061586635176330035, 'adj rsquared': 0.6605959297030544, 'constant': 1.6827734935161818, 'hedge ratio': 0.0939929213179424, 'half life': 12.0, 'p-value of adf test': 0.005171706776411388, 'adjustment coef': -0.03570381419852912}]}
# {'Trading Day': '20240830', 'Coint Pairs and Params': [{'asset 1': 'SMH', 'asset 2': 'AMD', 'res mean': 3.6159337632386437e-12, 'res std': 0.315284212812349, 'adj rsquared': 0.9510246027130113, 'constant': -34.941333634437584, 'hedge ratio': 0.753767313501255, 'half life': 10.5, 'p-value of adf test': 0.002150433027002196, 'adjustment coef': -0.05777572351400603}, {'asset 1': 'SMH', 'asset 2': 'AMAT', 'res mean': 1.1298722641255993e-12, 'res std': 0.4029516239889357, 'adj rsquared': 0.9175620949563422, 'constant': 23.4603464860339, 'hedge ratio': 0.7084767687895768, 'half life': 5.5, 'p-value of adf test': 0.0014559426479266566, 'adjustment coef': -0.14463225836849297}, {'asset 1': 'SOXX', 'asset 2': 'AMD', 'res mean': -1.7841910285381181e-12, 'res std': 0.32792851139116697, 'adj rsquared': 0.9503171396565154, 'constant': -29.289901293613994, 'hedge ratio': 0.7759712946610133, 'half life': 10.5, 'p-value of adf test': 0.00937931876245462, 'adjustment coef': -0.060668865521603055}, {'asset 1': 'SOXX', 'asset 2': 'AMAT', 'res mean': 1.095183203384901e-12, 'res std': 0.3441543240360928, 'adj rsquared': 0.940920402506469, 'constant': 29.879098120727306, 'hedge ratio': 0.724061591732039, 'half life': 4.0, 'p-value of adf test': 0.001217976659472098, 'adjustment coef': -0.1848974407717806}, {'asset 1': 'TSM', 'asset 2': 'AMD', 'res mean': -2.089578652558908e-12, 'res std': 0.4096580312191223, 'adj rsquared': 0.9114786324464931, 'constant': -0.9502437268603359, 'hedge ratio': 0.8732971810655059, 'half life': 13.0, 'p-value of adf test': 0.028581176714669393, 'adjustment coef': -0.04602000190232605}, {'asset 1': 'TSM', 'asset 2': 'AMAT', 'res mean': -5.065258753744181e-12, 'res std': 0.4536651296673728, 'adj rsquared': 0.8973845944081273, 'constant': 59.129449185447235, 'hedge ratio': 0.7982737865079266, 'half life': 6.5, 'p-value of adf test': 0.0019915228439912756, 'adjustment coef': -0.1198220180273297}, {'asset 1': 'AMD', 'asset 2': 'AMAT', 'res mean': -2.023407082910686e-13, 'res std': 0.48247650524089825, 'adj rsquared': 0.8874800780706662, 'constant': 59.64178178335661, 'hedge ratio': 0.9175563036457026, 'half life': 6.5, 'p-value of adf test': 0.0008061327857488621, 'adjustment coef': -0.10193173942770045}, {'asset 1': 'AMD', 'asset 2': 'QCOM', 'res mean': 9.821522512655252e-13, 'res std': 0.47638986279307866, 'adj rsquared': 0.8082205478598536, 'constant': 76.79023548437843, 'hedge ratio': 0.6538927145024445, 'half life': 15.0, 'p-value of adf test': 0.023674963292382677, 'adjustment coef': -0.04836893142379367}]}

# %%
df_results = pd.DataFrame(results)
df_results.to_csv("parameters/cointPair_params_formation2_ds60_weighted.csv", sep = ";", index= False)
pd.read_csv("parameters/cointPair_params_formation2_ds60_weighted.csv", sep = ";")
# Out:
#     Trading Day                             Coint Pairs and Params
# 0      20240605  [{'asset 1': 'SMH', 'asset 2': 'TSM', 'res mea...
# 1      20240606  [{'asset 1': 'SMH', 'asset 2': 'SOXX', 'res me...
# 2      20240607  [{'asset 1': 'SMH', 'asset 2': 'SOXX', 'res me...
# 3      20240610                                                 []
# 4      20240611                                                 []
# ..          ...                                                ...
# 56     20240826  [{'asset 1': 'AMD', 'asset 2': 'QCOM', 'res me...
# 57     20240827  [{'asset 1': 'SMH', 'asset 2': 'TSM', 'res mea...
# 58     20240828  [{'asset 1': 'SOXX', 'asset 2': 'AMD', 'res me...
# 59     20240829  [{'asset 1': 'SMH', 'asset 2': 'SOXX', 'res me...
# 60     20240830  [{'asset 1': 'SMH', 'asset 2': 'AMD', 'res mea...
#
# [61 rows x 2 columns]
