# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json
from alpaca_trade_api.rest import REST, TimeFrame
import tables
import os
from datetime import datetime

# %%
url = "https://paper-api.alpaca.markets/v2/calendar?start=2024-06-01T00%3A00%3A00Z&end=2024-08-31T23%3A59%3A59Z" ## get trading days from 2024-06-01 to 2024-08-31

key = json.loads(open("key.txt","r").read())
api_key_id = key["APCA-API-KEY-ID"]
api_secret_key = key["APCA-API-SECRET-KEY"]

headers = {
    "accept": "application/json",
    "APCA-API-KEY-ID": api_key_id,
    "APCA-API-SECRET-KEY": api_secret_key
}

api = REST(api_key_id, api_secret_key, base_url='https://data.alpaca.markets/v2')

# %%
response = requests.get(url, headers=headers)
df_market_hours = pd.DataFrame(response.json())
df_market_hours["market open"] = df_market_hours["date"] + "T" + df_market_hours["open"] + ":00Z"
df_market_hours["market close"] = df_market_hours["date"] + "T" + df_market_hours["close"] + ":00Z"
df_market_hours = df_market_hours[["date", "market open", "market close"]]
df_market_hours.set_index("date", inplace= True)

# %%
df_market_hours.head()
# Out:
#                      market open          market close
# date
# 2024-06-03  2024-06-03T09:30:00Z  2024-06-03T16:00:00Z
# 2024-06-04  2024-06-04T09:30:00Z  2024-06-04T16:00:00Z
# 2024-06-05  2024-06-05T09:30:00Z  2024-06-05T16:00:00Z
# 2024-06-06  2024-06-06T09:30:00Z  2024-06-06T16:00:00Z
# 2024-06-07  2024-06-07T09:30:00Z  2024-06-07T16:00:00Z

# %%
symbol_list = ["SMH", "SOXX","NVDA", "TSM", "AVGO", "TXN", "AMD", "ASML", "ADI", "AMAT", "QCOM", "KLAC","INTC"]
folder_name = "data"

# Ensure the folder exists
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

for symbol in symbol_list:
    for i in range(len(df_market_hours)):
        date = df_market_hours.index[i]
               
        market_open = df_market_hours.iloc[i]["market open"]
        market_close = df_market_hours.iloc[i]["market close"]

        # Convert the date string to a datetime object if necessary
        if isinstance(date, str):
            date = datetime.strptime(date, '%Y-%m-%d')  # Adjust format if your date string is different

        # Create a file name for the CSV file using the symbol and date
        csv_filename = os.path.join(folder_name, f"{symbol}_{date.strftime('%Y%m%d')}_quote.csv")

        # Check if the file already exists
        if os.path.exists(csv_filename):
            print(f"Data for {symbol} on {date.strftime('%Y-%m-%d')} already exists. Skipping download.")
            continue  # Skip to the next iteration if the file exists

        print(f"Start downloading quote data for {symbol} on {date.strftime('%Y-%m-%d')}...")
        quotes = api.get_quotes(symbol=symbol, start=market_open, end=market_close, limit=3000000).df  
        print(f"Finished downloading quote data for {symbol} on {date.strftime('%Y-%m-%d')}")

        # Save the quotes DataFrame to the CSV file
        quotes.to_csv(csv_filename, index=True)

        print(f"Saved data to {csv_filename}")
        print("--------------------")
# Out:
# Start downloading quote data for SMH on 2024-06-03...
# Finished downloading quote data for SMH on 2024-06-03
# Saved data to data\SMH_20240603_quote.csv
# --------------------
# Start downloading quote data for SMH on 2024-06-04...
# Finished downloading quote data for SMH on 2024-06-04
# Saved data to data\SMH_20240604_quote.csv
# --------------------
# Start downloading quote data for SMH on 2024-06-05...
# Finished downloading quote data for SMH on 2024-06-05
# Saved data to data\SMH_20240605_quote.csv
# --------------------
# Start downloading quote data for SMH on 2024-06-06...
# Finished downloading quote data for SMH on 2024-06-06
# Saved data to data\SMH_20240606_quote.csv
# --------------------
# Start downloading quote data for SMH on 2024-06-07...
# Finished downloading quote data for SMH on 2024-06-07
# Saved data to data\SMH_20240607_quote.csv
# --------------------
# Start downloading quote data for SMH on 2024-06-10...
# Finished downloading quote data for SMH on 2024-06-10
# Saved data to data\SMH_20240610_quote.csv
# --------------------
# Start downloading quote data for SMH on 2024-06-11...
# Finished downloading quote data for SMH on 2024-06-11
# Saved data to data\SMH_20240611_quote.csv
# --------------------
# Start downloading quote data for SMH on 2024-06-12...
# Finished downloading quote data for SMH on 2024-06-12
# Saved data to data\SMH_20240612_quote.csv
# --------------------
# Start downloading quote data for SMH on 2024-06-13...
# Finished downloading quote data for SMH on 2024-06-13
# Saved data to data\SMH_20240613_quote.csv
# --------------------
# Start downloading quote data for SMH on 2024-06-14...
# Finished downloading quote data for SMH on 2024-06-14
# Saved data to data\SMH_20240614_quote.csv
# --------------------
# Start downloading quote data for SMH on 2024-06-17...
# Finished downloading quote data for SMH on 2024-06-17
# Saved data to data\SMH_20240617_quote.csv
# --------------------
# Start downloading quote data for SMH on 2024-06-18...
# Finished downloading quote data for SMH on 2024-06-18
# Saved data to data\SMH_20240618_quote.csv
# --------------------
# Start downloading quote data for SMH on 2024-06-20...
# Finished downloading quote data for SMH on 2024-06-20
# Saved data to data\SMH_20240620_quote.csv
# --------------------
# Start downloading quote data for SMH on 2024-06-21...
# Finished downloading quote data for SMH on 2024-06-21
# Saved data to data\SMH_20240621_quote.csv
# --------------------
# Start downloading quote data for SMH on 2024-06-24...
# Finished downloading quote data for SMH on 2024-06-24
# Saved data to data\SMH_20240624_quote.csv
# --------------------
# Start downloading quote data for SMH on 2024-06-25...
# Finished downloading quote data for SMH on 2024-06-25
# Saved data to data\SMH_20240625_quote.csv
# --------------------
# Start downloading quote data for SMH on 2024-06-26...
# Finished downloading quote data for SMH on 2024-06-26
# Saved data to data\SMH_20240626_quote.csv
# --------------------
# Start downloading quote data for SMH on 2024-06-27...
# Finished downloading quote data for SMH on 2024-06-27
# Saved data to data\SMH_20240627_quote.csv
# --------------------
# Start downloading quote data for SMH on 2024-06-28...
# Finished downloading quote data for SMH on 2024-06-28
# Saved data to data\SMH_20240628_quote.csv
# --------------------
# Start downloading quote data for SOXX on 2024-06-03...
# Finished downloading quote data for SOXX on 2024-06-03
# Saved data to data\SOXX_20240603_quote.csv
# --------------------
# Start downloading quote data for SOXX on 2024-06-04...
# Finished downloading quote data for SOXX on 2024-06-04
# Saved data to data\SOXX_20240604_quote.csv
# --------------------
# Start downloading quote data for SOXX on 2024-06-05...
# Finished downloading quote data for SOXX on 2024-06-05
# Saved data to data\SOXX_20240605_quote.csv
# --------------------
# Start downloading quote data for SOXX on 2024-06-06...
# Finished downloading quote data for SOXX on 2024-06-06
# Saved data to data\SOXX_20240606_quote.csv
# --------------------
# Start downloading quote data for SOXX on 2024-06-07...
# Finished downloading quote data for SOXX on 2024-06-07
# Saved data to data\SOXX_20240607_quote.csv
# --------------------
# Start downloading quote data for SOXX on 2024-06-10...
# Finished downloading quote data for SOXX on 2024-06-10
# Saved data to data\SOXX_20240610_quote.csv
# --------------------
# Start downloading quote data for SOXX on 2024-06-11...
# Finished downloading quote data for SOXX on 2024-06-11
# Saved data to data\SOXX_20240611_quote.csv
# --------------------
# Start downloading quote data for SOXX on 2024-06-12...
# Finished downloading quote data for SOXX on 2024-06-12
# Saved data to data\SOXX_20240612_quote.csv
# --------------------
# Start downloading quote data for SOXX on 2024-06-13...
# Finished downloading quote data for SOXX on 2024-06-13
# Saved data to data\SOXX_20240613_quote.csv
# --------------------
# Start downloading quote data for SOXX on 2024-06-14...
# Finished downloading quote data for SOXX on 2024-06-14
# Saved data to data\SOXX_20240614_quote.csv
# --------------------
# Start downloading quote data for SOXX on 2024-06-17...
# Finished downloading quote data for SOXX on 2024-06-17
# Saved data to data\SOXX_20240617_quote.csv
# --------------------
# Start downloading quote data for SOXX on 2024-06-18...
# Finished downloading quote data for SOXX on 2024-06-18
# Saved data to data\SOXX_20240618_quote.csv
# --------------------
# Start downloading quote data for SOXX on 2024-06-20...
# Finished downloading quote data for SOXX on 2024-06-20
# Saved data to data\SOXX_20240620_quote.csv
# --------------------
# Start downloading quote data for SOXX on 2024-06-21...
# Finished downloading quote data for SOXX on 2024-06-21
# Saved data to data\SOXX_20240621_quote.csv
# --------------------
# Start downloading quote data for SOXX on 2024-06-24...
# Finished downloading quote data for SOXX on 2024-06-24
# Saved data to data\SOXX_20240624_quote.csv
# --------------------
# Start downloading quote data for SOXX on 2024-06-25...
# Finished downloading quote data for SOXX on 2024-06-25
# Saved data to data\SOXX_20240625_quote.csv
# --------------------
# Start downloading quote data for SOXX on 2024-06-26...
# Finished downloading quote data for SOXX on 2024-06-26
# Saved data to data\SOXX_20240626_quote.csv
# --------------------
# Start downloading quote data for SOXX on 2024-06-27...
# Finished downloading quote data for SOXX on 2024-06-27
# Saved data to data\SOXX_20240627_quote.csv
# --------------------
# Start downloading quote data for SOXX on 2024-06-28...
# Finished downloading quote data for SOXX on 2024-06-28
# Saved data to data\SOXX_20240628_quote.csv
# --------------------
# Start downloading quote data for NVDA on 2024-06-03...
# Finished downloading quote data for NVDA on 2024-06-03
# Saved data to data\NVDA_20240603_quote.csv
# --------------------
# Start downloading quote data for NVDA on 2024-06-04...
# Finished downloading quote data for NVDA on 2024-06-04
# Saved data to data\NVDA_20240604_quote.csv
# --------------------
# Start downloading quote data for NVDA on 2024-06-05...
# Finished downloading quote data for NVDA on 2024-06-05
# Saved data to data\NVDA_20240605_quote.csv
# --------------------
# Start downloading quote data for NVDA on 2024-06-06...
# Finished downloading quote data for NVDA on 2024-06-06
# Saved data to data\NVDA_20240606_quote.csv
# --------------------
# Start downloading quote data for NVDA on 2024-06-07...
# Finished downloading quote data for NVDA on 2024-06-07
# Saved data to data\NVDA_20240607_quote.csv
# --------------------
# Start downloading quote data for NVDA on 2024-06-10...
# Finished downloading quote data for NVDA on 2024-06-10
# Saved data to data\NVDA_20240610_quote.csv
# --------------------
# Start downloading quote data for NVDA on 2024-06-11...
# Finished downloading quote data for NVDA on 2024-06-11
# Saved data to data\NVDA_20240611_quote.csv
# --------------------
# Start downloading quote data for NVDA on 2024-06-12...
# Finished downloading quote data for NVDA on 2024-06-12
# Saved data to data\NVDA_20240612_quote.csv
# --------------------
# Start downloading quote data for NVDA on 2024-06-13...
# Finished downloading quote data for NVDA on 2024-06-13
# Saved data to data\NVDA_20240613_quote.csv
# --------------------
# Start downloading quote data for NVDA on 2024-06-14...
# Finished downloading quote data for NVDA on 2024-06-14
# Saved data to data\NVDA_20240614_quote.csv
# --------------------
# Start downloading quote data for NVDA on 2024-06-17...
# Finished downloading quote data for NVDA on 2024-06-17
# Saved data to data\NVDA_20240617_quote.csv
# --------------------
# Start downloading quote data for NVDA on 2024-06-18...
# Finished downloading quote data for NVDA on 2024-06-18
# Saved data to data\NVDA_20240618_quote.csv
# --------------------
# Start downloading quote data for NVDA on 2024-06-20...
# Finished downloading quote data for NVDA on 2024-06-20
# Saved data to data\NVDA_20240620_quote.csv
# --------------------
# Start downloading quote data for NVDA on 2024-06-21...
# Finished downloading quote data for NVDA on 2024-06-21
# Saved data to data\NVDA_20240621_quote.csv
# --------------------
# Start downloading quote data for NVDA on 2024-06-24...
# Finished downloading quote data for NVDA on 2024-06-24
# Saved data to data\NVDA_20240624_quote.csv
# --------------------
# Start downloading quote data for NVDA on 2024-06-25...
# Finished downloading quote data for NVDA on 2024-06-25
# Saved data to data\NVDA_20240625_quote.csv
# --------------------
# Start downloading quote data for NVDA on 2024-06-26...
# Finished downloading quote data for NVDA on 2024-06-26
# Saved data to data\NVDA_20240626_quote.csv
# --------------------
# Start downloading quote data for NVDA on 2024-06-27...
# Finished downloading quote data for NVDA on 2024-06-27
# Saved data to data\NVDA_20240627_quote.csv
# --------------------
# Start downloading quote data for NVDA on 2024-06-28...
# Finished downloading quote data for NVDA on 2024-06-28
# Saved data to data\NVDA_20240628_quote.csv
# --------------------
# Start downloading quote data for TSM on 2024-06-03...
# Finished downloading quote data for TSM on 2024-06-03
# Saved data to data\TSM_20240603_quote.csv
# --------------------
# Start downloading quote data for TSM on 2024-06-04...
# Finished downloading quote data for TSM on 2024-06-04
# Saved data to data\TSM_20240604_quote.csv
# --------------------
# Start downloading quote data for TSM on 2024-06-05...
# Finished downloading quote data for TSM on 2024-06-05
# Saved data to data\TSM_20240605_quote.csv
# --------------------
# Start downloading quote data for TSM on 2024-06-06...
# Finished downloading quote data for TSM on 2024-06-06
# Saved data to data\TSM_20240606_quote.csv
# --------------------
# Start downloading quote data for TSM on 2024-06-07...
# Finished downloading quote data for TSM on 2024-06-07
# Saved data to data\TSM_20240607_quote.csv
# --------------------
# Start downloading quote data for TSM on 2024-06-10...
# Finished downloading quote data for TSM on 2024-06-10
# Saved data to data\TSM_20240610_quote.csv
# --------------------
# Start downloading quote data for TSM on 2024-06-11...
# Finished downloading quote data for TSM on 2024-06-11
# Saved data to data\TSM_20240611_quote.csv
# --------------------
# Start downloading quote data for TSM on 2024-06-12...
# Finished downloading quote data for TSM on 2024-06-12
# Saved data to data\TSM_20240612_quote.csv
# --------------------
# Start downloading quote data for TSM on 2024-06-13...
# Finished downloading quote data for TSM on 2024-06-13
# Saved data to data\TSM_20240613_quote.csv
# --------------------
# Start downloading quote data for TSM on 2024-06-14...
# Finished downloading quote data for TSM on 2024-06-14
# Saved data to data\TSM_20240614_quote.csv
# --------------------
# Start downloading quote data for TSM on 2024-06-17...
# Finished downloading quote data for TSM on 2024-06-17
# Saved data to data\TSM_20240617_quote.csv
# --------------------
# Start downloading quote data for TSM on 2024-06-18...
# Finished downloading quote data for TSM on 2024-06-18
# Saved data to data\TSM_20240618_quote.csv
# --------------------
# Start downloading quote data for TSM on 2024-06-20...
# Finished downloading quote data for TSM on 2024-06-20
# Saved data to data\TSM_20240620_quote.csv
# --------------------
# Start downloading quote data for TSM on 2024-06-21...
# Finished downloading quote data for TSM on 2024-06-21
# Saved data to data\TSM_20240621_quote.csv
# --------------------
# Start downloading quote data for TSM on 2024-06-24...
# Finished downloading quote data for TSM on 2024-06-24
# Saved data to data\TSM_20240624_quote.csv
# --------------------
# Start downloading quote data for TSM on 2024-06-25...
# Finished downloading quote data for TSM on 2024-06-25
# Saved data to data\TSM_20240625_quote.csv
# --------------------
# Start downloading quote data for TSM on 2024-06-26...
# Finished downloading quote data for TSM on 2024-06-26
# Saved data to data\TSM_20240626_quote.csv
# --------------------
# Start downloading quote data for TSM on 2024-06-27...
# Finished downloading quote data for TSM on 2024-06-27
# Saved data to data\TSM_20240627_quote.csv
# --------------------
# Start downloading quote data for TSM on 2024-06-28...
# Finished downloading quote data for TSM on 2024-06-28
# Saved data to data\TSM_20240628_quote.csv
# --------------------
# Start downloading quote data for AVGO on 2024-06-03...
# Finished downloading quote data for AVGO on 2024-06-03
# Saved data to data\AVGO_20240603_quote.csv
# --------------------
# Start downloading quote data for AVGO on 2024-06-04...
# Finished downloading quote data for AVGO on 2024-06-04
# Saved data to data\AVGO_20240604_quote.csv
# --------------------
# Start downloading quote data for AVGO on 2024-06-05...
# Finished downloading quote data for AVGO on 2024-06-05
# Saved data to data\AVGO_20240605_quote.csv
# --------------------
# Start downloading quote data for AVGO on 2024-06-06...
# Finished downloading quote data for AVGO on 2024-06-06
# Saved data to data\AVGO_20240606_quote.csv
# --------------------
# Start downloading quote data for AVGO on 2024-06-07...
# Finished downloading quote data for AVGO on 2024-06-07
# Saved data to data\AVGO_20240607_quote.csv
# --------------------
# Start downloading quote data for AVGO on 2024-06-10...
# Finished downloading quote data for AVGO on 2024-06-10
# Saved data to data\AVGO_20240610_quote.csv
# --------------------
# Start downloading quote data for AVGO on 2024-06-11...
# Finished downloading quote data for AVGO on 2024-06-11
# Saved data to data\AVGO_20240611_quote.csv
# --------------------
# Start downloading quote data for AVGO on 2024-06-12...
# Finished downloading quote data for AVGO on 2024-06-12
# Saved data to data\AVGO_20240612_quote.csv
# --------------------
# Start downloading quote data for AVGO on 2024-06-13...
# Finished downloading quote data for AVGO on 2024-06-13
# Saved data to data\AVGO_20240613_quote.csv
# --------------------
# Start downloading quote data for AVGO on 2024-06-14...
# Finished downloading quote data for AVGO on 2024-06-14
# Saved data to data\AVGO_20240614_quote.csv
# --------------------
# Start downloading quote data for AVGO on 2024-06-17...
# Finished downloading quote data for AVGO on 2024-06-17
# Saved data to data\AVGO_20240617_quote.csv
# --------------------
# Start downloading quote data for AVGO on 2024-06-18...
# Finished downloading quote data for AVGO on 2024-06-18
# Saved data to data\AVGO_20240618_quote.csv
# --------------------
# Start downloading quote data for AVGO on 2024-06-20...
# Finished downloading quote data for AVGO on 2024-06-20
# Saved data to data\AVGO_20240620_quote.csv
# --------------------
# Start downloading quote data for AVGO on 2024-06-21...
# Finished downloading quote data for AVGO on 2024-06-21
# Saved data to data\AVGO_20240621_quote.csv
# --------------------
# Start downloading quote data for AVGO on 2024-06-24...
# Finished downloading quote data for AVGO on 2024-06-24
# Saved data to data\AVGO_20240624_quote.csv
# --------------------
# Start downloading quote data for AVGO on 2024-06-25...
# Finished downloading quote data for AVGO on 2024-06-25
# Saved data to data\AVGO_20240625_quote.csv
# --------------------
# Start downloading quote data for AVGO on 2024-06-26...
# Finished downloading quote data for AVGO on 2024-06-26
# Saved data to data\AVGO_20240626_quote.csv
# --------------------
# Start downloading quote data for AVGO on 2024-06-27...
# Finished downloading quote data for AVGO on 2024-06-27
# Saved data to data\AVGO_20240627_quote.csv
# --------------------
# Start downloading quote data for AVGO on 2024-06-28...
# Finished downloading quote data for AVGO on 2024-06-28
# Saved data to data\AVGO_20240628_quote.csv
# --------------------
# Start downloading quote data for TXN on 2024-06-03...
# Finished downloading quote data for TXN on 2024-06-03
# Saved data to data\TXN_20240603_quote.csv
# --------------------
# Start downloading quote data for TXN on 2024-06-04...
# Finished downloading quote data for TXN on 2024-06-04
# Saved data to data\TXN_20240604_quote.csv
# --------------------
# Start downloading quote data for TXN on 2024-06-05...
# Finished downloading quote data for TXN on 2024-06-05
# Saved data to data\TXN_20240605_quote.csv
# --------------------
# Start downloading quote data for TXN on 2024-06-06...
# Finished downloading quote data for TXN on 2024-06-06
# Saved data to data\TXN_20240606_quote.csv
# --------------------
# Start downloading quote data for TXN on 2024-06-07...
# Finished downloading quote data for TXN on 2024-06-07
# Saved data to data\TXN_20240607_quote.csv
# --------------------
# Start downloading quote data for TXN on 2024-06-10...
# Finished downloading quote data for TXN on 2024-06-10
# Saved data to data\TXN_20240610_quote.csv
# --------------------
# Start downloading quote data for TXN on 2024-06-11...
# Finished downloading quote data for TXN on 2024-06-11
# Saved data to data\TXN_20240611_quote.csv
# --------------------
# Start downloading quote data for TXN on 2024-06-12...
# Finished downloading quote data for TXN on 2024-06-12
# Saved data to data\TXN_20240612_quote.csv
# --------------------
# Start downloading quote data for TXN on 2024-06-13...
# Finished downloading quote data for TXN on 2024-06-13
# Saved data to data\TXN_20240613_quote.csv
# --------------------
# Start downloading quote data for TXN on 2024-06-14...
# Finished downloading quote data for TXN on 2024-06-14
# Saved data to data\TXN_20240614_quote.csv
# --------------------
# Start downloading quote data for TXN on 2024-06-17...
# Finished downloading quote data for TXN on 2024-06-17
# Saved data to data\TXN_20240617_quote.csv
# --------------------
# Start downloading quote data for TXN on 2024-06-18...
# Finished downloading quote data for TXN on 2024-06-18
# Saved data to data\TXN_20240618_quote.csv
# --------------------
# Start downloading quote data for TXN on 2024-06-20...
# Finished downloading quote data for TXN on 2024-06-20
# Saved data to data\TXN_20240620_quote.csv
# --------------------
# Start downloading quote data for TXN on 2024-06-21...
# Finished downloading quote data for TXN on 2024-06-21
# Saved data to data\TXN_20240621_quote.csv
# --------------------
# Start downloading quote data for TXN on 2024-06-24...
# Finished downloading quote data for TXN on 2024-06-24
# Saved data to data\TXN_20240624_quote.csv
# --------------------
# Start downloading quote data for TXN on 2024-06-25...
# Finished downloading quote data for TXN on 2024-06-25
# Saved data to data\TXN_20240625_quote.csv
# --------------------
# Start downloading quote data for TXN on 2024-06-26...
# Finished downloading quote data for TXN on 2024-06-26
# Saved data to data\TXN_20240626_quote.csv
# --------------------
# Start downloading quote data for TXN on 2024-06-27...
# Finished downloading quote data for TXN on 2024-06-27
# Saved data to data\TXN_20240627_quote.csv
# --------------------
# Start downloading quote data for TXN on 2024-06-28...
# Finished downloading quote data for TXN on 2024-06-28
# Saved data to data\TXN_20240628_quote.csv
# --------------------
# Start downloading quote data for AMD on 2024-06-03...
# Finished downloading quote data for AMD on 2024-06-03
# Saved data to data\AMD_20240603_quote.csv
# --------------------
# Start downloading quote data for AMD on 2024-06-04...
# Finished downloading quote data for AMD on 2024-06-04
# Saved data to data\AMD_20240604_quote.csv
# --------------------
# Start downloading quote data for AMD on 2024-06-05...
# Finished downloading quote data for AMD on 2024-06-05
# Saved data to data\AMD_20240605_quote.csv
# --------------------
# Start downloading quote data for AMD on 2024-06-06...
# Finished downloading quote data for AMD on 2024-06-06
# Saved data to data\AMD_20240606_quote.csv
# --------------------
# Start downloading quote data for AMD on 2024-06-07...
# Finished downloading quote data for AMD on 2024-06-07
# Saved data to data\AMD_20240607_quote.csv
# --------------------
# Start downloading quote data for AMD on 2024-06-10...
# Finished downloading quote data for AMD on 2024-06-10
# Saved data to data\AMD_20240610_quote.csv
# --------------------
# Start downloading quote data for AMD on 2024-06-11...
# Finished downloading quote data for AMD on 2024-06-11
# Saved data to data\AMD_20240611_quote.csv
# --------------------
# Start downloading quote data for AMD on 2024-06-12...
# Finished downloading quote data for AMD on 2024-06-12
# Saved data to data\AMD_20240612_quote.csv
# --------------------
# Start downloading quote data for AMD on 2024-06-13...
# Finished downloading quote data for AMD on 2024-06-13
# Saved data to data\AMD_20240613_quote.csv
# --------------------
# Start downloading quote data for AMD on 2024-06-14...
# Finished downloading quote data for AMD on 2024-06-14
# Saved data to data\AMD_20240614_quote.csv
# --------------------
# Start downloading quote data for AMD on 2024-06-17...
# Finished downloading quote data for AMD on 2024-06-17
# Saved data to data\AMD_20240617_quote.csv
# --------------------
# Start downloading quote data for AMD on 2024-06-18...
# Finished downloading quote data for AMD on 2024-06-18
# Saved data to data\AMD_20240618_quote.csv
# --------------------
# Start downloading quote data for AMD on 2024-06-20...
# Finished downloading quote data for AMD on 2024-06-20
# Saved data to data\AMD_20240620_quote.csv
# --------------------
# Start downloading quote data for AMD on 2024-06-21...
# Finished downloading quote data for AMD on 2024-06-21
# Saved data to data\AMD_20240621_quote.csv
# --------------------
# Start downloading quote data for AMD on 2024-06-24...
# Finished downloading quote data for AMD on 2024-06-24
# Saved data to data\AMD_20240624_quote.csv
# --------------------
# Start downloading quote data for AMD on 2024-06-25...
# Finished downloading quote data for AMD on 2024-06-25
# Saved data to data\AMD_20240625_quote.csv
# --------------------
# Start downloading quote data for AMD on 2024-06-26...
# Finished downloading quote data for AMD on 2024-06-26
# Saved data to data\AMD_20240626_quote.csv
# --------------------
# Start downloading quote data for AMD on 2024-06-27...
# Finished downloading quote data for AMD on 2024-06-27
# Saved data to data\AMD_20240627_quote.csv
# --------------------
# Start downloading quote data for AMD on 2024-06-28...
# Finished downloading quote data for AMD on 2024-06-28
# Saved data to data\AMD_20240628_quote.csv
# --------------------
# Start downloading quote data for ASML on 2024-06-03...
# Finished downloading quote data for ASML on 2024-06-03
# Saved data to data\ASML_20240603_quote.csv
# --------------------
# Start downloading quote data for ASML on 2024-06-04...
# Finished downloading quote data for ASML on 2024-06-04
# Saved data to data\ASML_20240604_quote.csv
# --------------------
# Start downloading quote data for ASML on 2024-06-05...
# Finished downloading quote data for ASML on 2024-06-05
# Saved data to data\ASML_20240605_quote.csv
# --------------------
# Start downloading quote data for ASML on 2024-06-06...
# Finished downloading quote data for ASML on 2024-06-06
# Saved data to data\ASML_20240606_quote.csv
# --------------------
# Start downloading quote data for ASML on 2024-06-07...
# Finished downloading quote data for ASML on 2024-06-07
# Saved data to data\ASML_20240607_quote.csv
# --------------------
# Start downloading quote data for ASML on 2024-06-10...
# Finished downloading quote data for ASML on 2024-06-10
# Saved data to data\ASML_20240610_quote.csv
# --------------------
# Start downloading quote data for ASML on 2024-06-11...
# Finished downloading quote data for ASML on 2024-06-11
# Saved data to data\ASML_20240611_quote.csv
# --------------------
# Start downloading quote data for ASML on 2024-06-12...
# Finished downloading quote data for ASML on 2024-06-12
# Saved data to data\ASML_20240612_quote.csv
# --------------------
# Start downloading quote data for ASML on 2024-06-13...
# Finished downloading quote data for ASML on 2024-06-13
# Saved data to data\ASML_20240613_quote.csv
# --------------------
# Start downloading quote data for ASML on 2024-06-14...
# Finished downloading quote data for ASML on 2024-06-14
# Saved data to data\ASML_20240614_quote.csv
# --------------------
# Start downloading quote data for ASML on 2024-06-17...
# Finished downloading quote data for ASML on 2024-06-17
# Saved data to data\ASML_20240617_quote.csv
# --------------------
# Start downloading quote data for ASML on 2024-06-18...
# Finished downloading quote data for ASML on 2024-06-18
# Saved data to data\ASML_20240618_quote.csv
# --------------------
# Start downloading quote data for ASML on 2024-06-20...
# Finished downloading quote data for ASML on 2024-06-20
# Saved data to data\ASML_20240620_quote.csv
# --------------------
# Start downloading quote data for ASML on 2024-06-21...
# Finished downloading quote data for ASML on 2024-06-21
# Saved data to data\ASML_20240621_quote.csv
# --------------------
# Start downloading quote data for ASML on 2024-06-24...
# Finished downloading quote data for ASML on 2024-06-24
# Saved data to data\ASML_20240624_quote.csv
# --------------------
# Start downloading quote data for ASML on 2024-06-25...
# Finished downloading quote data for ASML on 2024-06-25
# Saved data to data\ASML_20240625_quote.csv
# --------------------
# Start downloading quote data for ASML on 2024-06-26...
# Finished downloading quote data for ASML on 2024-06-26
# Saved data to data\ASML_20240626_quote.csv
# --------------------
# Start downloading quote data for ASML on 2024-06-27...
# Finished downloading quote data for ASML on 2024-06-27
# Saved data to data\ASML_20240627_quote.csv
# --------------------
# Start downloading quote data for ASML on 2024-06-28...
# Finished downloading quote data for ASML on 2024-06-28
# Saved data to data\ASML_20240628_quote.csv
# --------------------
# Start downloading quote data for ADI on 2024-06-03...
# Finished downloading quote data for ADI on 2024-06-03
# Saved data to data\ADI_20240603_quote.csv
# --------------------
# Start downloading quote data for ADI on 2024-06-04...
# Finished downloading quote data for ADI on 2024-06-04
# Saved data to data\ADI_20240604_quote.csv
# --------------------
# Start downloading quote data for ADI on 2024-06-05...
# Finished downloading quote data for ADI on 2024-06-05
# Saved data to data\ADI_20240605_quote.csv
# --------------------
# Start downloading quote data for ADI on 2024-06-06...
# Finished downloading quote data for ADI on 2024-06-06
# Saved data to data\ADI_20240606_quote.csv
# --------------------
# Start downloading quote data for ADI on 2024-06-07...
# Finished downloading quote data for ADI on 2024-06-07
# Saved data to data\ADI_20240607_quote.csv
# --------------------
# Start downloading quote data for ADI on 2024-06-10...
# Finished downloading quote data for ADI on 2024-06-10
# Saved data to data\ADI_20240610_quote.csv
# --------------------
# Start downloading quote data for ADI on 2024-06-11...
# Finished downloading quote data for ADI on 2024-06-11
# Saved data to data\ADI_20240611_quote.csv
# --------------------
# Start downloading quote data for ADI on 2024-06-12...
# Finished downloading quote data for ADI on 2024-06-12
# Saved data to data\ADI_20240612_quote.csv
# --------------------
# Start downloading quote data for ADI on 2024-06-13...
# Finished downloading quote data for ADI on 2024-06-13
# Saved data to data\ADI_20240613_quote.csv
# --------------------
# Start downloading quote data for ADI on 2024-06-14...
# Finished downloading quote data for ADI on 2024-06-14
# Saved data to data\ADI_20240614_quote.csv
# --------------------
# Start downloading quote data for ADI on 2024-06-17...
# Finished downloading quote data for ADI on 2024-06-17
# Saved data to data\ADI_20240617_quote.csv
# --------------------
# Start downloading quote data for ADI on 2024-06-18...
# Finished downloading quote data for ADI on 2024-06-18
# Saved data to data\ADI_20240618_quote.csv
# --------------------
# Start downloading quote data for ADI on 2024-06-20...
# Finished downloading quote data for ADI on 2024-06-20
# Saved data to data\ADI_20240620_quote.csv
# --------------------
# Start downloading quote data for ADI on 2024-06-21...
# Finished downloading quote data for ADI on 2024-06-21
# Saved data to data\ADI_20240621_quote.csv
# --------------------
# Start downloading quote data for ADI on 2024-06-24...
# Finished downloading quote data for ADI on 2024-06-24
# Saved data to data\ADI_20240624_quote.csv
# --------------------
# Start downloading quote data for ADI on 2024-06-25...
# Finished downloading quote data for ADI on 2024-06-25
# Saved data to data\ADI_20240625_quote.csv
# --------------------
# Start downloading quote data for ADI on 2024-06-26...
# Finished downloading quote data for ADI on 2024-06-26
# Saved data to data\ADI_20240626_quote.csv
# --------------------
# Start downloading quote data for ADI on 2024-06-27...
# Finished downloading quote data for ADI on 2024-06-27
# Saved data to data\ADI_20240627_quote.csv
# --------------------
# Start downloading quote data for ADI on 2024-06-28...
# Finished downloading quote data for ADI on 2024-06-28
# Saved data to data\ADI_20240628_quote.csv
# --------------------
# Start downloading quote data for AMAT on 2024-06-03...
# Finished downloading quote data for AMAT on 2024-06-03
# Saved data to data\AMAT_20240603_quote.csv
# --------------------
# Start downloading quote data for AMAT on 2024-06-04...
# Finished downloading quote data for AMAT on 2024-06-04
# Saved data to data\AMAT_20240604_quote.csv
# --------------------
# Start downloading quote data for AMAT on 2024-06-05...
# Finished downloading quote data for AMAT on 2024-06-05
# Saved data to data\AMAT_20240605_quote.csv
# --------------------
# Start downloading quote data for AMAT on 2024-06-06...
# Finished downloading quote data for AMAT on 2024-06-06
# Saved data to data\AMAT_20240606_quote.csv
# --------------------
# Start downloading quote data for AMAT on 2024-06-07...
# Finished downloading quote data for AMAT on 2024-06-07
# Saved data to data\AMAT_20240607_quote.csv
# --------------------
# Start downloading quote data for AMAT on 2024-06-10...
# Finished downloading quote data for AMAT on 2024-06-10
# Saved data to data\AMAT_20240610_quote.csv
# --------------------
# Start downloading quote data for AMAT on 2024-06-11...
# Finished downloading quote data for AMAT on 2024-06-11
# Saved data to data\AMAT_20240611_quote.csv
# --------------------
# Start downloading quote data for AMAT on 2024-06-12...
# Finished downloading quote data for AMAT on 2024-06-12
# Saved data to data\AMAT_20240612_quote.csv
# --------------------
# Start downloading quote data for AMAT on 2024-06-13...
# Finished downloading quote data for AMAT on 2024-06-13
# Saved data to data\AMAT_20240613_quote.csv
# --------------------
# Start downloading quote data for AMAT on 2024-06-14...
# Finished downloading quote data for AMAT on 2024-06-14
# Saved data to data\AMAT_20240614_quote.csv
# --------------------
# Start downloading quote data for AMAT on 2024-06-17...
# Finished downloading quote data for AMAT on 2024-06-17
# Saved data to data\AMAT_20240617_quote.csv
# --------------------
# Start downloading quote data for AMAT on 2024-06-18...
# Finished downloading quote data for AMAT on 2024-06-18
# Saved data to data\AMAT_20240618_quote.csv
# --------------------
# Start downloading quote data for AMAT on 2024-06-20...
# Finished downloading quote data for AMAT on 2024-06-20
# Saved data to data\AMAT_20240620_quote.csv
# --------------------
# Start downloading quote data for AMAT on 2024-06-21...
# Finished downloading quote data for AMAT on 2024-06-21
# Saved data to data\AMAT_20240621_quote.csv
# --------------------
# Start downloading quote data for AMAT on 2024-06-24...
# Finished downloading quote data for AMAT on 2024-06-24
# Saved data to data\AMAT_20240624_quote.csv
# --------------------
# Start downloading quote data for AMAT on 2024-06-25...
# Finished downloading quote data for AMAT on 2024-06-25
# Saved data to data\AMAT_20240625_quote.csv
# --------------------
# Start downloading quote data for AMAT on 2024-06-26...
# Finished downloading quote data for AMAT on 2024-06-26
# Saved data to data\AMAT_20240626_quote.csv
# --------------------
# Start downloading quote data for AMAT on 2024-06-27...
# Finished downloading quote data for AMAT on 2024-06-27
# Saved data to data\AMAT_20240627_quote.csv
# --------------------
# Start downloading quote data for AMAT on 2024-06-28...
# Finished downloading quote data for AMAT on 2024-06-28
# Saved data to data\AMAT_20240628_quote.csv
# --------------------
# Start downloading quote data for QCOM on 2024-06-03...
# Finished downloading quote data for QCOM on 2024-06-03
# Saved data to data\QCOM_20240603_quote.csv
# --------------------
# Start downloading quote data for QCOM on 2024-06-04...
# Finished downloading quote data for QCOM on 2024-06-04
# Saved data to data\QCOM_20240604_quote.csv
# --------------------
# Start downloading quote data for QCOM on 2024-06-05...
# Finished downloading quote data for QCOM on 2024-06-05
# Saved data to data\QCOM_20240605_quote.csv
# --------------------
# Start downloading quote data for QCOM on 2024-06-06...
# Finished downloading quote data for QCOM on 2024-06-06
# Saved data to data\QCOM_20240606_quote.csv
# --------------------
# Start downloading quote data for QCOM on 2024-06-07...
# Finished downloading quote data for QCOM on 2024-06-07
# Saved data to data\QCOM_20240607_quote.csv
# --------------------
# Start downloading quote data for QCOM on 2024-06-10...
# Finished downloading quote data for QCOM on 2024-06-10
# Saved data to data\QCOM_20240610_quote.csv
# --------------------
# Start downloading quote data for QCOM on 2024-06-11...
# Finished downloading quote data for QCOM on 2024-06-11
# Saved data to data\QCOM_20240611_quote.csv
# --------------------
# Start downloading quote data for QCOM on 2024-06-12...
# Finished downloading quote data for QCOM on 2024-06-12
# Saved data to data\QCOM_20240612_quote.csv
# --------------------
# Start downloading quote data for QCOM on 2024-06-13...
# Finished downloading quote data for QCOM on 2024-06-13
# Saved data to data\QCOM_20240613_quote.csv
# --------------------
# Start downloading quote data for QCOM on 2024-06-14...
# Finished downloading quote data for QCOM on 2024-06-14
# Saved data to data\QCOM_20240614_quote.csv
# --------------------
# Start downloading quote data for QCOM on 2024-06-17...
# Finished downloading quote data for QCOM on 2024-06-17
# Saved data to data\QCOM_20240617_quote.csv
# --------------------
# Start downloading quote data for QCOM on 2024-06-18...
# Finished downloading quote data for QCOM on 2024-06-18
# Saved data to data\QCOM_20240618_quote.csv
# --------------------
# Start downloading quote data for QCOM on 2024-06-20...
# Finished downloading quote data for QCOM on 2024-06-20
# Saved data to data\QCOM_20240620_quote.csv
# --------------------
# Start downloading quote data for QCOM on 2024-06-21...
# Finished downloading quote data for QCOM on 2024-06-21
# Saved data to data\QCOM_20240621_quote.csv
# --------------------
# Start downloading quote data for QCOM on 2024-06-24...
# Finished downloading quote data for QCOM on 2024-06-24
# Saved data to data\QCOM_20240624_quote.csv
# --------------------
# Start downloading quote data for QCOM on 2024-06-25...
# Finished downloading quote data for QCOM on 2024-06-25
# Saved data to data\QCOM_20240625_quote.csv
# --------------------
# Start downloading quote data for QCOM on 2024-06-26...
# Finished downloading quote data for QCOM on 2024-06-26
# Saved data to data\QCOM_20240626_quote.csv
# --------------------
# Start downloading quote data for QCOM on 2024-06-27...
# Finished downloading quote data for QCOM on 2024-06-27
# Saved data to data\QCOM_20240627_quote.csv
# --------------------
# Start downloading quote data for QCOM on 2024-06-28...
# Finished downloading quote data for QCOM on 2024-06-28
# Saved data to data\QCOM_20240628_quote.csv
# --------------------
# Start downloading quote data for KLAC on 2024-06-03...
# Finished downloading quote data for KLAC on 2024-06-03
# Saved data to data\KLAC_20240603_quote.csv
# --------------------
# Start downloading quote data for KLAC on 2024-06-04...
# Finished downloading quote data for KLAC on 2024-06-04
# Saved data to data\KLAC_20240604_quote.csv
# --------------------
# Start downloading quote data for KLAC on 2024-06-05...
# Finished downloading quote data for KLAC on 2024-06-05
# Saved data to data\KLAC_20240605_quote.csv
# --------------------
# Start downloading quote data for KLAC on 2024-06-06...
# Finished downloading quote data for KLAC on 2024-06-06
# Saved data to data\KLAC_20240606_quote.csv
# --------------------
# Start downloading quote data for KLAC on 2024-06-07...
# Finished downloading quote data for KLAC on 2024-06-07
# Saved data to data\KLAC_20240607_quote.csv
# --------------------
# Start downloading quote data for KLAC on 2024-06-10...
# Finished downloading quote data for KLAC on 2024-06-10
# Saved data to data\KLAC_20240610_quote.csv
# --------------------
# Start downloading quote data for KLAC on 2024-06-11...
# Finished downloading quote data for KLAC on 2024-06-11
# Saved data to data\KLAC_20240611_quote.csv
# --------------------
# Start downloading quote data for KLAC on 2024-06-12...
# Finished downloading quote data for KLAC on 2024-06-12
# Saved data to data\KLAC_20240612_quote.csv
# --------------------
# Start downloading quote data for KLAC on 2024-06-13...
# Finished downloading quote data for KLAC on 2024-06-13
# Saved data to data\KLAC_20240613_quote.csv
# --------------------
# Start downloading quote data for KLAC on 2024-06-14...
# Finished downloading quote data for KLAC on 2024-06-14
# Saved data to data\KLAC_20240614_quote.csv
# --------------------
# Start downloading quote data for KLAC on 2024-06-17...
# Finished downloading quote data for KLAC on 2024-06-17
# Saved data to data\KLAC_20240617_quote.csv
# --------------------
# Start downloading quote data for KLAC on 2024-06-18...
# Finished downloading quote data for KLAC on 2024-06-18
# Saved data to data\KLAC_20240618_quote.csv
# --------------------
# Start downloading quote data for KLAC on 2024-06-20...
# Finished downloading quote data for KLAC on 2024-06-20
# Saved data to data\KLAC_20240620_quote.csv
# --------------------
# Start downloading quote data for KLAC on 2024-06-21...
# Finished downloading quote data for KLAC on 2024-06-21
# Saved data to data\KLAC_20240621_quote.csv
# --------------------
# Start downloading quote data for KLAC on 2024-06-24...
# Finished downloading quote data for KLAC on 2024-06-24
# Saved data to data\KLAC_20240624_quote.csv
# --------------------
# Start downloading quote data for KLAC on 2024-06-25...
# Finished downloading quote data for KLAC on 2024-06-25
# Saved data to data\KLAC_20240625_quote.csv
# --------------------
# Start downloading quote data for KLAC on 2024-06-26...
# Finished downloading quote data for KLAC on 2024-06-26
# Saved data to data\KLAC_20240626_quote.csv
# --------------------
# Start downloading quote data for KLAC on 2024-06-27...
# Finished downloading quote data for KLAC on 2024-06-27
# Saved data to data\KLAC_20240627_quote.csv
# --------------------
# Start downloading quote data for KLAC on 2024-06-28...
# Finished downloading quote data for KLAC on 2024-06-28
# Saved data to data\KLAC_20240628_quote.csv
# --------------------
# Start downloading quote data for INTC on 2024-06-03...
# Finished downloading quote data for INTC on 2024-06-03
# Saved data to data\INTC_20240603_quote.csv
# --------------------
# Start downloading quote data for INTC on 2024-06-04...
# Finished downloading quote data for INTC on 2024-06-04
# Saved data to data\INTC_20240604_quote.csv
# --------------------
# Start downloading quote data for INTC on 2024-06-05...
# Finished downloading quote data for INTC on 2024-06-05
# Saved data to data\INTC_20240605_quote.csv
# --------------------
# Start downloading quote data for INTC on 2024-06-06...
# Finished downloading quote data for INTC on 2024-06-06
# Saved data to data\INTC_20240606_quote.csv
# --------------------
# Start downloading quote data for INTC on 2024-06-07...
# Finished downloading quote data for INTC on 2024-06-07
# Saved data to data\INTC_20240607_quote.csv
# --------------------
# Start downloading quote data for INTC on 2024-06-10...
# Finished downloading quote data for INTC on 2024-06-10
# Saved data to data\INTC_20240610_quote.csv
# --------------------
# Start downloading quote data for INTC on 2024-06-11...
# Finished downloading quote data for INTC on 2024-06-11
# Saved data to data\INTC_20240611_quote.csv
# --------------------
# Start downloading quote data for INTC on 2024-06-12...
# Finished downloading quote data for INTC on 2024-06-12
# Saved data to data\INTC_20240612_quote.csv
# --------------------
# Start downloading quote data for INTC on 2024-06-13...
# Finished downloading quote data for INTC on 2024-06-13
# Saved data to data\INTC_20240613_quote.csv
# --------------------
# Start downloading quote data for INTC on 2024-06-14...
# Finished downloading quote data for INTC on 2024-06-14
# Saved data to data\INTC_20240614_quote.csv
# --------------------
# Start downloading quote data for INTC on 2024-06-17...
# Finished downloading quote data for INTC on 2024-06-17
# Saved data to data\INTC_20240617_quote.csv
# --------------------
# Start downloading quote data for INTC on 2024-06-18...
# Finished downloading quote data for INTC on 2024-06-18
# Saved data to data\INTC_20240618_quote.csv
# --------------------
# Start downloading quote data for INTC on 2024-06-20...
# Finished downloading quote data for INTC on 2024-06-20
# Saved data to data\INTC_20240620_quote.csv
# --------------------
# Start downloading quote data for INTC on 2024-06-21...
# Finished downloading quote data for INTC on 2024-06-21
# Saved data to data\INTC_20240621_quote.csv
# --------------------
# Start downloading quote data for INTC on 2024-06-24...
# Finished downloading quote data for INTC on 2024-06-24
# Saved data to data\INTC_20240624_quote.csv
# --------------------
# Start downloading quote data for INTC on 2024-06-25...
# Finished downloading quote data for INTC on 2024-06-25
# Saved data to data\INTC_20240625_quote.csv
# --------------------
# Start downloading quote data for INTC on 2024-06-26...
# Finished downloading quote data for INTC on 2024-06-26
# Saved data to data\INTC_20240626_quote.csv
# --------------------
# Start downloading quote data for INTC on 2024-06-27...
# Finished downloading quote data for INTC on 2024-06-27
# Saved data to data\INTC_20240627_quote.csv
# --------------------
# Start downloading quote data for INTC on 2024-06-28...
# Finished downloading quote data for INTC on 2024-06-28
# Saved data to data\INTC_20240628_quote.csv
# --------------------

# %%
# Specify the folder where the CSV files are located
folder_name = "data"

# Get the list of all files in the folder
all_files = os.listdir(folder_name)

# Filter the list to include only .csv files
csv_files = [f for f in all_files if f.endswith('.csv')]

# Print the list of .csv files
print(csv_files)
# Out:
# ['ADI_20240603_quote.csv', 'ADI_20240604_quote.csv', 'ADI_20240605_quote.csv', 'ADI_20240606_quote.csv', 'ADI_20240607_quote.csv', 'ADI_20240610_quote.csv', 'ADI_20240611_quote.csv', 'ADI_20240612_quote.csv', 'ADI_20240613_quote.csv', 'ADI_20240614_quote.csv', 'ADI_20240617_quote.csv', 'ADI_20240618_quote.csv', 'ADI_20240620_quote.csv', 'ADI_20240621_quote.csv', 'ADI_20240624_quote.csv', 'ADI_20240625_quote.csv', 'ADI_20240626_quote.csv', 'ADI_20240627_quote.csv', 'ADI_20240628_quote.csv', 'ADI_20240701_quote.csv', 'ADI_20240702_quote.csv', 'ADI_20240703_quote.csv', 'ADI_20240705_quote.csv', 'ADI_20240708_quote.csv', 'ADI_20240709_quote.csv', 'ADI_20240710_quote.csv', 'ADI_20240711_quote.csv', 'ADI_20240712_quote.csv', 'ADI_20240715_quote.csv', 'ADI_20240716_quote.csv', 'ADI_20240717_quote.csv', 'ADI_20240718_quote.csv', 'ADI_20240719_quote.csv', 'ADI_20240722_quote.csv', 'ADI_20240723_quote.csv', 'ADI_20240724_quote.csv', 'ADI_20240725_quote.csv', 'ADI_20240726_quote.csv', 'ADI_20240729_quote.csv', 'ADI_20240730_quote.csv', 'ADI_20240731_quote.csv', 'ADI_20240801_quote.csv', 'ADI_20240802_quote.csv', 'ADI_20240805_quote.csv', 'ADI_20240806_quote.csv', 'ADI_20240807_quote.csv', 'ADI_20240808_quote.csv', 'ADI_20240809_quote.csv', 'ADI_20240812_quote.csv', 'ADI_20240813_quote.csv', 'ADI_20240814_quote.csv', 'ADI_20240815_quote.csv', 'ADI_20240816_quote.csv', 'ADI_20240819_quote.csv', 'ADI_20240820_quote.csv', 'ADI_20240821_quote.csv', 'ADI_20240822_quote.csv', 'ADI_20240823_quote.csv', 'ADI_20240826_quote.csv', 'ADI_20240827_quote.csv', 'ADI_20240828_quote.csv', 'ADI_20240829_quote.csv', 'ADI_20240830_quote.csv', 'AMAT_20240603_quote.csv', 'AMAT_20240604_quote.csv', 'AMAT_20240605_quote.csv', 'AMAT_20240606_quote.csv', 'AMAT_20240607_quote.csv', 'AMAT_20240610_quote.csv', 'AMAT_20240611_quote.csv', 'AMAT_20240612_quote.csv', 'AMAT_20240613_quote.csv', 'AMAT_20240614_quote.csv', 'AMAT_20240617_quote.csv', 'AMAT_20240618_quote.csv', 'AMAT_20240620_quote.csv', 'AMAT_20240621_quote.csv', 'AMAT_20240624_quote.csv', 'AMAT_20240625_quote.csv', 'AMAT_20240626_quote.csv', 'AMAT_20240627_quote.csv', 'AMAT_20240628_quote.csv', 'AMAT_20240701_quote.csv', 'AMAT_20240702_quote.csv', 'AMAT_20240703_quote.csv', 'AMAT_20240705_quote.csv', 'AMAT_20240708_quote.csv', 'AMAT_20240709_quote.csv', 'AMAT_20240710_quote.csv', 'AMAT_20240711_quote.csv', 'AMAT_20240712_quote.csv', 'AMAT_20240715_quote.csv', 'AMAT_20240716_quote.csv', 'AMAT_20240717_quote.csv', 'AMAT_20240718_quote.csv', 'AMAT_20240719_quote.csv', 'AMAT_20240722_quote.csv', 'AMAT_20240723_quote.csv', 'AMAT_20240724_quote.csv', 'AMAT_20240725_quote.csv', 'AMAT_20240726_quote.csv', 'AMAT_20240729_quote.csv', 'AMAT_20240730_quote.csv', 'AMAT_20240731_quote.csv', 'AMAT_20240801_quote.csv', 'AMAT_20240802_quote.csv', 'AMAT_20240805_quote.csv', 'AMAT_20240806_quote.csv', 'AMAT_20240807_quote.csv', 'AMAT_20240808_quote.csv', 'AMAT_20240809_quote.csv', 'AMAT_20240812_quote.csv', 'AMAT_20240813_quote.csv', 'AMAT_20240814_quote.csv', 'AMAT_20240815_quote.csv', 'AMAT_20240816_quote.csv', 'AMAT_20240819_quote.csv', 'AMAT_20240820_quote.csv', 'AMAT_20240821_quote.csv', 'AMAT_20240822_quote.csv', 'AMAT_20240823_quote.csv', 'AMAT_20240826_quote.csv', 'AMAT_20240827_quote.csv', 'AMAT_20240828_quote.csv', 'AMAT_20240829_quote.csv', 'AMAT_20240830_quote.csv', 'AMD_20240603_quote.csv', 'AMD_20240604_quote.csv', 'AMD_20240605_quote.csv', 'AMD_20240606_quote.csv', 'AMD_20240607_quote.csv', 'AMD_20240610_quote.csv', 'AMD_20240611_quote.csv', 'AMD_20240612_quote.csv', 'AMD_20240613_quote.csv', 'AMD_20240614_quote.csv', 'AMD_20240617_quote.csv', 'AMD_20240618_quote.csv', 'AMD_20240620_quote.csv', 'AMD_20240621_quote.csv', 'AMD_20240624_quote.csv', 'AMD_20240625_quote.csv', 'AMD_20240626_quote.csv', 'AMD_20240627_quote.csv', 'AMD_20240628_quote.csv', 'AMD_20240701_quote.csv', 'AMD_20240702_quote.csv', 'AMD_20240703_quote.csv', 'AMD_20240705_quote.csv', 'AMD_20240708_quote.csv', 'AMD_20240709_quote.csv', 'AMD_20240 ...

# %%
# Check if there is missing data(number of quote > download limit)
for csv in csv_files:
    df = pd.read_csv("data/"   + csv)
    num_rows = len(df)
    # Check if the number of rows is exactly 2,000,001
    if num_rows == 3000000:
        print(f"{csv} has exactly 3,000,000 rows.")

# %%
# Re-download quote data for 2024-08-02
# quotes_20240802 = api.get_quotes(symbol="NVDA", start="2024-08-02T09:30:00Z", end="2024-08-02T16:00:00Z", limit=3000000).df  
# quotes_20240802.to_csv("data/NVDA_20240802_quote.csv", index=True)

# Re-download quote data for 2024-08-05
# quotes_20240805 = api.get_quotes(symbol="NVDA", start="2024-08-05T09:30:00Z", end="2024-08-05T16:00:00Z", limit=3000000).df  
# quotes_20240805.to_csv("data/NVDA_20240805_quote.csv", index=True)
